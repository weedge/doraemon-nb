# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/baby_llm_vae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd /content && git clone https://github.com/ai-bot-pro/baby-llm.git -b feat/vae
# Out:
# Cloning into 'baby-llm'...
# remote: Enumerating objects: 1126, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 1126 (delta 77), reused 123 (delta 47), pack-reused 942 (from 1)
# Receiving objects: 100% (1126/1126), 12.00 MiB | 33.74 MiB/s, done.
# Resolving deltas: 100% (696/696), done.

# %%
# %cd /content/baby-llm
# Out:
# /content/baby-llm

# %% [markdown]
# # GaussianMLPVAE
# - A simple implementation of Gaussian MLP Encoder and Decoder

# %%
# !python -m modules.VAE.GaussianMLPVAE.train
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 9.91M/9.91M [00:00<00:00, 12.8MB/s]
# Extracting ./datas/datasets/MNIST/raw/train-images-idx3-ubyte.gz to ./datas/datasets/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 28.9k/28.9k [00:00<00:00, 340kB/s]
# Extracting ./datas/datasets/MNIST/raw/train-labels-idx1-ubyte.gz to ./datas/datasets/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 1.65M/1.65M [00:00<00:00, 3.20MB/s]
# Extracting ./datas/datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to ./datas/datasets/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 4.54k/4.54k [00:00<00:00, 16.2MB/s]
# Extracting ./datas/datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./datas/datasets/MNIST/raw
#
# train_dataset Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./datas/datasets
#     Split: Train
#     StandardTransform
# Transform: Compose(
# ...

# %%
from IPython.display import Image
Image(filename='/content/baby-llm/datas/gen/GaussianMLPVAE/test_src_0.png')

# %%
from IPython.display import Image
Image(filename='/content/baby-llm/datas/gen/GaussianMLPVAE/test_generated_0.png')

# %%
from IPython.display import Image
Image(filename='/content/baby-llm/datas/gen/GaussianMLPVAE/generated_sample.png')

# %% [markdown]
# # QA-VAE

# %%
# !python -m modules.VAE.VQVAE.train
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train_dataset Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./datas/datasets
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            ) test_dataset Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./datas/datasets
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )
# train_loader <torch.utils.data.dataloader.DataLoader object at 0x7a4c20b80a90> test_loader <torch.utils.data.dataloader.DataLoader object at 0x7a4c20b80bb0>
# VQVAEModel(
#   (encoder): Encoder(
#     (strided_conv_1): Conv2d(3, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (strided_conv_2): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (residual_conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
from IPython.display import Image
Image(filename='/content/baby-llm/datas/gen/VQVAE/test_src_0.png')

# %%
Image(filename='/content/baby-llm/datas/gen/VQVAE/test_generated_0.png')

# %%
Image(filename='/content/baby-llm/datas/gen/VQVAE/test_src_1.png')

# %%
Image(filename='/content/baby-llm/datas/gen/VQVAE/test_generated_1.png')

# %%
Image(filename='/content/baby-llm/datas/gen/VQVAE/generated_sample.png')
