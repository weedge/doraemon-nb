# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/transformers_llm_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # intro
# GLM-4v-9(chat), MiniCPM-V-2.6, Qwen2-VL 2B-instuct, 7B-instuct, Llama-3.2-11B-Vision-Instruct on transformers inference(generate) with streamer(streaming)

# %%
# !wget "https://www.barnorama.com/wp-content/uploads/2016/12/03-Confusing-Pictures.jpg"
# Out:
# --2024-09-13 08:57:44--  https://www.barnorama.com/wp-content/uploads/2016/12/03-Confusing-Pictures.jpg
# Resolving www.barnorama.com (www.barnorama.com)... 15.204.140.74
# Connecting to www.barnorama.com (www.barnorama.com)|15.204.140.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46296 (45K) [image/jpeg]
# Saving to: ‘03-Confusing-Pictures.jpg’
#
# 03-Confusing-Pictur 100%[===================>]  45.21K   238KB/s    in 0.2s
#
# 2024-09-13 08:57:46 (238 KB/s) - ‘03-Confusing-Pictures.jpg’ saved [46296/46296]

# %% [markdown]
# ## GLM-4V-9

# %%
# !pip install -q tiktoken flash_attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 62.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.7 MB/s eta 0:00:00
#   Building wheel for flash_attn (setup.py) ... done

# %%
import torch
from PIL import Image
from transformers import AutoModelForCausalLM, AutoTokenizer

device = "cuda"

tokenizer = AutoTokenizer.from_pretrained("THUDM/glm-4v-9b", trust_remote_code=True)

query = '描述这张图片'
image = Image.open("03-Confusing-Pictures.jpg").convert('RGB')
inputs = tokenizer.apply_chat_template([{"role": "user", "image": image, "content": query}],
                                       add_generation_prompt=True, tokenize=True, return_tensors="pt",
                                       return_dict=True)  # chat mode

inputs = inputs.to(device)
model = AutoModelForCausalLM.from_pretrained(
    "THUDM/glm-4v-9b",
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    trust_remote_code=True
).to(device).eval()

gen_kwargs = {"max_length": 2500, "do_sample": True, "top_k": 1}
with torch.no_grad():
    outputs = model.generate(**inputs, **gen_kwargs)
    outputs = outputs[:, inputs['input_ids'].shape[1]:]
    print(tokenizer.decode(outputs[0]))
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.22k [00:00<?, ?B/s]
# tokenization_chatglm.py:   0%|          | 0.00/17.5k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/glm-4v-9b:
# - tokenization_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer.model:   0%|          | 0.00/2.62M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# configuration_chatglm.py:   0%|          | 0.00/2.57k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/glm-4v-9b:
# - configuration_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_chatglm.py:   0%|          | 0.00/57.0k [00:00<?, ?B/s]
# visual.py:   0%|          | 0.00/7.00k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/glm-4v-9b:
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/THUDM/glm-4v-9b:
# - modeling_chatglm.py
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/111k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/15 [00:00<?, ?it/s]
# model-00001-of-00015.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00002-of-00015.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00003-of-00015.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00004-of-00015.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00005-of-00015.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00006-of-00015.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00007-of-00015.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00008-of-00015.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00009-of-00015.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00010-of-00015.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00011-of-00015.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00012-of-00015.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00013-of-00015.safetensors:   0%|          | 0.00/1.96G [00:00<?, ?B/s]
# model-00014-of-00015.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00015-of-00015.safetensors:   0%|          | 0.00/811M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/15 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# 这张图片展示了一个穿着黄色上衣的男子站在一辆黄色SUV车的后备箱上，正在使用熨斗熨烫一件蓝色的衣物。他似乎在进行某种表演或展示。背景中可以看到其他车辆和建筑物，表明这可能是在一个城市的街道上。 <|endoftext|>

# %% [markdown]
# # MiniCPM-V

# %% [markdown]
# ## MiniCPM-V-2.6

# %%
# !pip install -q flash_attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 72.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for flash_attn (setup.py) ... done

# %%
import torch
import time
from PIL import Image
from transformers import AutoModel, AutoTokenizer

torch.manual_seed(0)

model = AutoModel.from_pretrained('openbmb/MiniCPM-V-2_6', trust_remote_code=True,
    attn_implementation='sdpa', torch_dtype=torch.bfloat16) # sdpa or flash_attention_2, no eager
model = model.eval().cuda()
tokenizer = AutoTokenizer.from_pretrained('openbmb/MiniCPM-V-2_6', trust_remote_code=True)

image = Image.open('03-Confusing-Pictures.jpg').convert('RGB')

# First round chat
question = "描述这张图片."
msgs = [{'role': 'user', 'content': [image, question]}]

s=time.time()
answer = model.chat(
    image=None,
    msgs=msgs,
    tokenizer=tokenizer
)
print(answer)
print("cost:",time.time()-s)

# Second round chat
# pass history context of multi-turn conversation
msgs.append({"role": "assistant", "content": [answer]})
msgs.append({"role": "user", "content": ["详细介绍"]})

s=time.time()
answer = model.chat(
    image=None,
    msgs=msgs,
    tokenizer=tokenizer
)
print(answer)
print("cost:",time.time()-s)

# %%
import torch
from PIL import Image
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained('openbmb/MiniCPM-V-2_6', trust_remote_code=True,
    attn_implementation='sdpa', torch_dtype=torch.bfloat16) # sdpa or flash_attention_2, no eager
model = model.eval().cuda()
tokenizer = AutoTokenizer.from_pretrained('openbmb/MiniCPM-V-2_6', trust_remote_code=True)

image1 = Image.open('03-Confusing-Pictures.jpg').convert('RGB')
image2 = Image.open('03-Confusing-Pictures.jpg').convert('RGB')
question = 'Compare image 1 and image 2, tell me about the differences between image 1 and image 2.'

msgs = [{'role': 'user', 'content': [image1, image2, question]}]
s=time.time()

answer = model.chat(
    image=None,
    msgs=msgs,
    tokenizer=tokenizer
)
print(answer)
print("cost:",time.time()-s)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# The images appear to be identical with no differences between them.
# cost: 4.712362766265869

# %% [markdown]
# # Qwen2-VL-7B-Instruct

# %%
# !pip install -q qwen-vl-utils
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 64.7 MB/s eta 0:00:00

# %%
# !pip show torch torchvision torchaudio transformers autoawq
# Out:
# WARNING: Package(s) not found: autoawq
# Name: torch
# Version: 2.4.0+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: accelerate, fastai, torchaudio, torchvision
# ---
# Name: torchvision
# Version: 0.19.0+cu121
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, torch
# Required-by: fastai
# ---
# Name: torchaudio
# Version: 2.4.0+cu121
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: torch
# Required-by:
# ---
# Name: transformers
# Version: 4.45.0.dev0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by:

# %%
# !pip uninstall -y transformers
# Out:
# Found existing installation: transformers 4.45.0.dev0
# Uninstalling transformers-4.45.0.dev0:
#   Successfully uninstalled transformers-4.45.0.dev0

# %%
# !pip install -q -U git+https://github.com/huggingface/transformers accelerate

# %%
# !pip install -q -U autoawq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.6/33.6 MB 69.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 35.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 119.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 94.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# torchaudio 2.4.0+cu121 requires torch==2.4.0, but you have torch 2.3.1 which is incompatible.
# torchvision 0.19.0+cu121 requires torch==2.4.0, but you have torch 2.3.1 which is incompatible.

# %%
# !pip install -q -U torch torchvision torchaudio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 118.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoawq 0.2.6 requires torch==2.3.1, but you have torch 2.4.1 which is incompatible.
# autoawq-kernels 0.0.7 requires torch==2.3.1, but you have torch 2.4.1 which is incompatible.

# %%
# !pip show torch torchvision torchaudio transformers autoawq
# Out:
# Name: torch
# Version: 2.4.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-nccl-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, autoawq, autoawq_kernels, fastai, torchaudio, torchvision
# ---
# Name: torchvision
# Version: 0.19.1
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, torch
# Required-by: fastai
# ---
# Name: torchaudio
# Version: 2.4.1
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: torch
# Required-by:
# ---
# Name: transformers
# Version: 4.45.0.dev0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: autoawq
# ---
# Name: autoawq
# Version: 0.2.6
# Summary: AutoAWQ implements the AWQ algorithm for 4-bit quantization with a 2x speedup during inference.
# Home-page: https://github.com/casper-hansen/AutoAWQ
# Author: Casper Hansen
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: accelerate, autoawq-kernels, datasets, tokenizers, torch, transformers, typing-extensions, zstandard
# Required-by:

# %%
# !wget "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg"
# Out:
# --2024-09-13 06:44:39--  https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg
# Resolving qianwen-res.oss-cn-beijing.aliyuncs.com (qianwen-res.oss-cn-beijing.aliyuncs.com)... 8.141.181.139
# Connecting to qianwen-res.oss-cn-beijing.aliyuncs.com (qianwen-res.oss-cn-beijing.aliyuncs.com)|8.141.181.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 496395 (485K) [image/jpeg]
# Saving to: ‘demo.jpeg’
#
# demo.jpeg           100%[===================>] 484.76K  1.08MB/s    in 0.4s
#
# 2024-09-13 06:44:40 (1.08 MB/s) - ‘demo.jpeg’ saved [496395/496395]

# %%
from PIL import Image
# Open the downloaded image in PIL
my_img = Image.open("demo.jpeg")
my_img.size
# Out:
# (2048, 1365)

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
from time import perf_counter

model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

# default: Load the model on the available device(s)
model = Qwen2VLForConditionalGeneration.from_pretrained(
    model_ckpt_name, torch_dtype="auto", device_map="cuda"
)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# model = Qwen2VLForConditionalGeneration.from_pretrained(
#     model_ckpt_name,
#     torch_dtype=torch.bfloat16,
#     attn_implementation="flash_attention_2",
#     device_map="auto",
# )

# default processer
processor = AutoProcessor.from_pretrained(model_ckpt_name)

# The default range for the number of visual tokens per image in the model is 4-16384. You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
# min_pixels = 256*28*28
# max_pixels = 1280*28*28
# processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct", min_pixels=min_pixels, max_pixels=max_pixels)

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
            },
            {"type": "text", "text": "描述下图片内容"},
        ],
    }
]

start_time = perf_counter()
# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# Inference: Generation of the output
generated_ids = model.generate(**inputs, max_new_tokens=128)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
print("cost:",perf_counter()-start_time)

# %% [markdown]
# ### streaming

# %% [markdown]
# Inference: Generation of the output with TextStreamer

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from transformers import TextStreamer

from qwen_vl_utils import process_vision_info
from time import perf_counter

model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-AWQ"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct"


# default: Load the model on the available device(s)
model = Qwen2VLForConditionalGeneration.from_pretrained(
    model_ckpt_name, torch_dtype="auto", device_map="cuda"
)


# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# model = Qwen2VLForConditionalGeneration.from_pretrained(
#     model_ckpt_name,
#     torch_dtype=torch.bfloat16,
#     attn_implementation="flash_attention_2",
#     device_map="auto",
# )

# default processer
processor = AutoProcessor.from_pretrained(model_ckpt_name)

# The default range for the number of visual tokens per image in the model is 4-16384. You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
# min_pixels = 256*28*28
# max_pixels = 1280*28*28
# processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct", min_pixels=min_pixels, max_pixels=max_pixels)

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
            },
            {"type": "text", "text": "描述下图片内容"},
        ],
    }
]

start_time = perf_counter()
# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")


# Inference: Generation of the output with TextStreamer
streamer = TextStreamer(processor, skip_prompt=True, skip_special_tokens=True)
generated_ids = model.generate(**inputs, max_new_tokens=128, streamer=streamer)


generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
print("cost:",perf_counter()-start_time)
# Out:
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# model.safetensors.index.json:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# 这张图片展示了一位坐在沙滩上的女人和一只大黄狗。女人穿着格子衬衫和黑色裤子，坐在沙滩上，她的手伸向狗的前爪，似乎在和狗互动。狗戴着一个彩色的项圈，看起来很友好。背景是广阔的海洋和天空，阳光从天空中照射下来，给整个场景增添了一种温暖的氛围。
# ['这张图片展示了一位坐在沙滩上的女人和一只大黄狗。女人穿着格子衬衫和黑色裤子，坐在沙滩上，她的手伸向狗的前爪，似乎在和狗互动。狗戴着一个彩色的项圈，看起来很友好。背景是广阔的海洋和天空，阳光从天空中照射下来，给整个场景增添了一种温暖的氛围。']
# cost: 14.863622368000051

# %% [markdown]
# Inference: Generation of the output with TextIteratorStreamer which stores print-ready text in a queue, to be used by a downstream application as an iterator:
#
# - if use flash-attention-2, see support GPU: https://github.com/Dao-AILab/flash-attention?tab=readme-ov-file#nvidia-cuda-support
# - if use pytorch sdpa, see: https://pytorch.org/docs/master/generated/torch.nn.functional.scaled_dot_product_attention.html

# %%
# !pip install flash-attn --no-build-isolation

# %%
# !pip show torch torchvision torchaudio transformers autoawq flash-attn
# Out:
# Name: torch
# Version: 2.4.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-nccl-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, autoawq, autoawq_kernels, fastai, flash-attn, torchaudio, torchvision
# ---
# Name: torchvision
# Version: 0.19.1
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, torch
# Required-by: fastai
# ---
# Name: torchaudio
# Version: 2.4.1
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: torch
# Required-by:
# ---
# Name: transformers
# Version: 4.45.0.dev0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: autoawq
# ---
# Name: autoawq
# Version: 0.2.6
# Summary: AutoAWQ implements the AWQ algorithm for 4-bit quantization with a 2x speedup during inference.
# Home-page: https://github.com/casper-hansen/AutoAWQ
# Author: Casper Hansen
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: accelerate, autoawq-kernels, datasets, tokenizers, torch, transformers, typing-extensions, zstandard
# Required-by:
# ---
# Name: flash-attn
# Version: 2.6.3
# Summary: Flash Attention: Fast and Memory-Efficient Exact Attention
# Home-page: https://github.com/Dao-AILab/flash-attention
# Author: Tri Dao
# Author-email: tri@tridao.me
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: einops, torch
# Required-by:

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from transformers import TextIteratorStreamer
import torch

from qwen_vl_utils import process_vision_info
from time import perf_counter

model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-AWQ"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct"


# default: Load the model on the available device(s)
#model = Qwen2VLForConditionalGeneration.from_pretrained(
#    model_ckpt_name, torch_dtype=torch.float16, device_map="cuda"
#)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# see detail: https://huggingface.co/docs/transformers/perf_infer_gpu_one
model = Qwen2VLForConditionalGeneration.from_pretrained(
     model_ckpt_name,
     torch_dtype=torch.bfloat16,
     attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
     #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
     device_map="cuda",
)

# default processer
#processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
min_pixels = 256*28*28
max_pixels = 1280*28*28
processor = AutoProcessor.from_pretrained(model_ckpt_name, min_pixels=min_pixels, max_pixels=max_pixels)

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
            },
            {"type": "text", "text": "描述下图片内容"},
        ],
    }
]
times=[]
start_time = perf_counter()
# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")


# Inference: Generation of the output with TextStreamer
streamer = TextIteratorStreamer(processor, skip_prompt=True, skip_special_tokens=True)
# Use Thread to run generation in background
# Otherwise, the process is blocked until generation is complete
# and no streaming effect can be observed.
from threading import Thread
generation_kwargs = dict(**inputs, streamer=streamer, max_new_tokens=128)
thread = Thread(target=model.generate, kwargs=generation_kwargs)
thread.start()

generated_text = ""
for new_text in streamer:
    #print(new_text)
    times.append(perf_counter() - start_time)
    generated_text += new_text
    start_time = perf_counter()
print(generated_text)

print("times",times)
print("total cost:",sum(times))
# Out:
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# model.safetensors.index.json:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# 这张图片展示了一位女性和一只狗在海滩上互动的场景。女性穿着格子衬衫和黑色裤子，坐在沙滩上，她的手伸向狗的前爪，似乎在进行高五或握手的动作。狗看起来很友好，正抬起前爪，似乎在回应女性的动作。背景是晴朗的天空和远处的海浪，给人一种宁静和放松的感觉。
# times [10.974506985000062, 0.05227334200003497, 0.03756508300011774, 0.039595087999941825, 0.03738587600014398, 0.03758597599994573, 0.0369501659999969, 0.03676405199985311, 0.03667982399997527, 0.03681435099997543, 0.03671764799992161, 0.03682590900007199, 0.03666948699992645, 0.03635597300012705, 0.03655481200007671, 0.037261187000012796, 0.036857571000155076, 0.037927195000065694, 0.03721780099999705, 0.03986541800009036, 0.038289664000103585, 0.03693945999998505, 0.03771102799987602, 0.03751624599999559, 0.03745947400011573, 0.03663922300006561, 0.03655142999991767, 0.036679875999880096, 0.038504222000028676, 0.03775697799983391, 0.037458495999999286, 0.03740841399985584, 0.037923784999975396, 0.037491858999828764, 0.03725386000019171, 0.037320139000030395, 0.03878725499998836, 0.03751736499998515, 0.03770871400001852, 0.03734971899984885, 0.03824118600005022, 0.0384436569997888, 0.03899886600015634, 0.03979654499994467, 0.03785821700012093, 0.0391617899999801, 0.037276984000072844, 0.03885998100008692, 0.03833682399999816, 0.03765177600007519, 0.03844414699983645, 0.03785927500007347, 0.03742149699996844, 0.04197290399997655, 0.037982931999977154, 0.03771856299999854, 0.037650301999974545, 0.03725373299994317, 0.03681721199995991, 0.03879945500011672, 0.03755675400020664, 0.03727125399996112, 0.03751543099997434, 0.03745023500005118, 0.03745520300003591, 0.03729649999991125, 0.03746508299991547, 0.03758832999983497, 0.038095988000122816, 0.03848658200013233, 0.037434216999827186, 0.03748339200001283, 0.038708335999899646, 0.03748546800011354, 0.038318134000064674, 0.03878953900016313, 0.037794957999949474, 0.039191914000184624, 0.038100000999975236, 0.037899647999893205, 0.03845292200003314, 0.03769756699989557, 0.0009553169998071098]
# total cost: 14.04967957000008

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from transformers import TextIteratorStreamer
import torch

from qwen_vl_utils import process_vision_info
from time import perf_counter

model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-AWQ"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct"


# default: Load the model on the available device(s)
#model = Qwen2VLForConditionalGeneration.from_pretrained(
#    model_ckpt_name, torch_dtype=torch.float16, device_map="cuda"
#)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# see detail: https://huggingface.co/docs/transformers/perf_infer_gpu_one
model = Qwen2VLForConditionalGeneration.from_pretrained(
     model_ckpt_name,
     torch_dtype=torch.bfloat16,
     attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
     #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
     device_map="cuda",
)

# default processer
#processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
min_pixels = 256*28*28
max_pixels = 1280*28*28
processor = AutoProcessor.from_pretrained(model_ckpt_name, min_pixels=min_pixels, max_pixels=max_pixels)

# Messages containing multiple images and a text query
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg"},
            {"type": "image", "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg"},
            {"type": "text", "text": "Identify the similarities between these images. Please reply to my message in chinese"},
        ],
    }
]
times=[]
start_time = perf_counter()


# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")



# Inference: Generation of the output with TextStreamer
streamer = TextIteratorStreamer(processor, skip_prompt=True, skip_special_tokens=True)
# Use Thread to run generation in background
# Otherwise, the process is blocked until generation is complete
# and no streaming effect can be observed.
from threading import Thread
generation_kwargs = dict(**inputs, streamer=streamer, max_new_tokens=128)
thread = Thread(target=model.generate, kwargs=generation_kwargs)
thread.start()

generated_text = ""
for new_text in streamer:
    #print(new_text)
    times.append(perf_counter() - start_time)
    generated_text += new_text
    start_time = perf_counter()
print(generated_text)

print("times",times)
print("total cost:",sum(times))
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#
D
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
def list_file(file_suffix: str = ".mp4", data_dir='/content'):
    import glob,os
    filenames = sorted(glob.glob(os.path.join(data_dir, f"*{file_suffix}")))
    return filenames
list_file()
# Out:
# ['/content/capture10_2024-09-15_20-10-42.mp4',
#  '/content/capture11_2024-09-15_20-10-44.mp4',
#  '/content/capture1_2024-09-15_20-10-21.mp4',
#  '/content/capture2_2024-09-15_20-10-25.mp4',
#  '/content/capture3_2024-09-15_20-10-27.mp4',
#  '/content/capture4_2024-09-15_20-10-29.mp4',
#  '/content/capture5_2024-09-15_20-10-31.mp4',
#  '/content/capture6_2024-09-15_20-10-33.mp4',
#  '/content/capture7_2024-09-15_20-10-35.mp4',
#  '/content/capture8_2024-09-15_20-10-37.mp4',
#  '/content/capture9_2024-09-15_20-10-39.mp4']

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from transformers import TextIteratorStreamer
import torch

from qwen_vl_utils import process_vision_info
from time import perf_counter

model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-AWQ"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct"


# default: Load the model on the available device(s)
#model = Qwen2VLForConditionalGeneration.from_pretrained(
#    model_ckpt_name, torch_dtype=torch.float16, device_map="cuda"
#)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# see detail: https://huggingface.co/docs/transformers/perf_infer_gpu_one
model = Qwen2VLForConditionalGeneration.from_pretrained(
     model_ckpt_name,
     torch_dtype=torch.bfloat16,
     attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
     #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
     device_map="cuda",
)

# default processer
#processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
min_pixels = 256*28*28
max_pixels = 1280*28*28
processor = AutoProcessor.from_pretrained(model_ckpt_name, min_pixels=min_pixels, max_pixels=max_pixels)




# Messages containing a images list as a video and a text query
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "video",
                "video": [
                    "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
                    "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
                    "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
                    "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
                ],
                "fps": 1.0,
            },
            {"type": "text", "text": "Describe this video. Please reply to my message in chinese"},
        ],
    }
]

# Messages containing a video and a text query
"""
352 x 240 (240p) (SD) (VCD Players)
480 x 360 (360p)
858 x 480 (480p)
1280 x 720 (720p) (HD) (Some HDTVs)
1920 x 1080 (1080p) (HD) (Blu-Ray Players, HDTV)
3860 x 2160 (2160p) (Ultra-HD) (4K Players / Televisions)

Apart from these, there are other variants of resolutions as well
640 x 480 (VGA, Standard Definition TVs)
1280 x 544 (Wide-Screen movies)
1920 x 816 or 1920 x 800 (Wide-screen movies)
"""
for video_file in list_file():
  print(video_file)
  messages = [
      {
          "role": "user",
          "content": [
              {
                  "type": "video",
                  "video": video_file,
                  "max_pixels": 360 * 420,
                  "fps": 1.0,
              },
              {"type": "text", "text": "Describe this video. Please reply to my message in chinese"},
          ],
      }
  ]

  times=[]
  start_time = perf_counter()


  # Preparation for inference
  text = processor.apply_chat_template(
      messages, tokenize=False, add_generation_prompt=True
  )
  image_inputs, video_inputs = process_vision_info(messages)
  inputs = processor(
      text=[text],
      images=image_inputs,
      videos=video_inputs,
      padding=True,
      return_tensors="pt",
  )
  inputs = inputs.to("cuda")



  # Inference: Generation of the output with TextStreamer
  streamer = TextIteratorStreamer(processor, skip_prompt=True, skip_special_tokens=True)
  # Use Thread to run generation in background
  # Otherwise, the process is blocked until generation is complete
  # and no streaming effect can be observed.
  from threading import Thread
  generation_kwargs = dict(**inputs, streamer=streamer, max_new_tokens=128)
  thread = Thread(target=model.generate, kwargs=generation_kwargs)
  thread.start()

  generated_text = ""
  for new_text in streamer:
      #print(new_text)
      times.append(perf_counter() - start_time)
      generated_text += new_text
      start_time = perf_counter()
  print(generated_text)

  print("times",times)
  print("total cost:",sum(times))
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /content/capture10_2024-09-15_20-10-42.mp4
# 这张视频显示了一位男士正在自拍。他拿着一部手机，手机的屏幕反射在他的脸上。背景中可以看到一些室内装饰，可能是房间的一部分。
# times [3.6618574740004988, 0.05083804300011252, 0.039060779999999795, 0.03813164799976221, 0.038122533000205294, 0.037427622999530286, 0.03764692500044475, 0.03769154299880029, 0.03777771500062954, 0.040194817000156036, 0.04116269000041939, 0.04055554700062203, 0.03942378200008534, 0.039092365999749745, 0.03964384299979429, 0.038808067998616025, 0.03908773399962229, 0.04299472000093374, 0.03969104800125933, 0.039581090000865515, 0.03804186799970921, 0.0389322289993288, 0.03857791599875782, 0.03741492399967683, 0.03915910800060374, 0.040358625001317705, 0.03914303399869823, 0.038517347999004414, 0.038486931000079494, 0.044384996999724535, 0.03810064000026614, 0.038006800999937695, 0.03851100599968049, 0.03819194999960018, 0.0007265370004461147]
# total cost: 4.965343902998939
# /content/capture11_2024-09-15_20-10-44.mp4
# 这张视频显示了一位男士正在自拍。他手里拿着一部手机，手机屏幕上显示了相机的界面。背景中可以看到一些光线和模糊的物体，可能是窗户或镜子。
# times [2.733038734000729, 0.03924066000035964, 0.03833557299913082, 0.039146982999227475, 0.038177640999492723, 0.037812357000802876, 0.03740248400026758, 0.037081337000927306, 0.037356931999966037, 0.03779359799955273, 0.03718436500093958, 0.03716880800129729, 0.03694954999991751, 0.03689556799872662, 0.03717873200002941, 0.037273227999321534, 0.03770787699977518, 0.03723368299870344, 0.037457525000718306, 0.03871056800016959, 0.03766191999966395, 0.038359514001058415, 0.03777644100046018, 0.03733553099846176, 0.03798318400004064, 0.03828900099870225, 0.03711829100029718, 0.03885657099999662, 0.03818874200078426, 0.03807532999962859, 0.037139513000511215, 0.03689200000007986, 0.038162755001394544, 0.037912472000243724, 0.038007412000297336, 0.03833112100073777, 0.037560302998826955, 0.03710158899957605, 0.036964889000955736, 0.0376824110007874, 0.0006230779999896185]
# total cost: 4.205168271002549
# /content/capture1_2024-09-15_20-10-21.mp4
# 这张照片显示一个人正在自拍。他手里拿着一部手机，手机的屏幕上显示着一些内容。背景中可以看到一些模糊的物体，可能是窗户或镜子。整体氛围显得比较自然和随意。
# times [2.8151296249998268, 0.040408027000012225, 0.03791165100119542, 0.03788915699988138, 0.03754048399969179, 0.03808572399975674, 0.038826961999802734, 0.03742678900016472, 0.03715854800066154, 0.03746503299953474, 0.03711643700080458, 0.038895263000085833, 0.03861691299971426, 0.03777772700050264, 0.037763874999654945, 0.03800609400059329, 0.037514077999730944, 0.03910646099939186, 0.03719311199893127, 0.03703641799984325, 0.037270175000230665, 0.03806480899947928, 
_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-7B-Instruct-AWQ"

model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int8"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-Int4"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct-AWQ"
model_ckpt_name = "Qwen/Qwen2-VL-2B-Instruct"


# default: Load the model on the available device(s)
#model = Qwen2VLForConditionalGeneration.from_pretrained(
#    model_ckpt_name, torch_dtype=torch.float16, device_map="cuda"
#)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# see detail: https://huggingface.co/docs/transformers/perf_infer_gpu_one
model = Qwen2VLForConditionalGeneration.from_pretrained(
     model_ckpt_name,
     torch_dtype=torch.bfloat16,
     attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
     #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
     device_map="cuda",
)

# default processer
#processor = AutoProcessor.from_pretrained("Qwen/Qwen2-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token count range of 256-1280, to balance speed and memory usage.
min_pixels = 256*28*28
max_pixels = 1280*28*28
processor = AutoProcessor.from_pretrained(model_ckpt_name, min_pixels=min_pixels, max_pixels=max_pixels)

# Sample messages for batch inference
messages2 = [
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg"},
            {"type": "image", "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg"},
            {"type": "text", "text": "What are the common elements in these pictures? Please reply to my message in chinese"},
        ],
    }
]
messages1 = [
    {"role": "system", "content": "You are a helpful assistant. Please reply to my message in chinese"},
    {"role": "user", "content": "Who are you? Please reply to my message in chinese"},
]
# Combine messages for batch processing
messages = [messages1, messages2]

times=[]
start_time = perf_counter()


# Preparation for batch inference
texts = [
    processor.apply_chat_template(msg, tokenize=False, add_generation_prompt=True)
    for msg in messages
]
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=texts,
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# Batch Inference
generated_ids = model.generate(**inputs, max_new_tokens=128)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_texts = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_texts)
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ['我是来自阿里云的大规模语言模型，我叫通义千问。', '这些图片中的共同元素包括：\n\n1. **海滩**：图片中都有海滩的元素。\n2. **狗**：图片中有狗。\n3. **人**：图片中有人。\n4. **互动**：图片中都有人和狗互动的场景。\n\n这些元素共同构成了这些图片的主题。']

# %% [markdown]
# # Llama-3.2-11B-Vision-Instruct

# %%
# !pip install "transformers>=4.45.0" --upgrade
# Out:
# Collecting transformers>=4.45.0
#   Downloading transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.45.0)
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.45.0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.45.0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.45.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.45.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.45.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.45.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.45.0) (2024.8.30)
# Downloading transformers-4.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 64.7 MB/s eta 0:00:00
# Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 90.1 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# Successfully installed tokenizers-0.20.0 transformers-4.45.0

# %%
# !huggingface-cli download unsloth/Llama-3.2-11B-Vision-Instruct --local-dir /content/models/unsloth/Llama-3.2-11B-Vision-Instruct --local-dir-use-symlinks False

# %%
import requests
import torch
from PIL import Image
from transformers import MllamaForConditionalGeneration, AutoProcessor

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
model_id = "unsloth/Llama-3.2-11B-Vision-Instruct"
model = MllamaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
    #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
    device_map="cuda",
)
processor = AutoProcessor.from_pretrained(model_id)

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/0052a70beed5bf71b92610a43a52df6d286cd5f3/diffusers/rabbit.jpg"
image = Image.open(requests.get(url, stream=True).raw)

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": "请用一句话描述图片内容，请用中文回复。"}
    ]}
]



input_text = processor.apply_chat_template(
    messages, add_generation_prompt=True,
)
inputs = processor(
    images=[image], text=[input_text], padding=True,return_tensors="pt",
).to(model.device)

output = model.generate(**inputs, max_new_tokens=70)

print(processor.decode(output[0][inputs["input_ids"].shape[-1]:]))


## The image depicts a rabbit dressed in a blue coat and brown vest, standing on a dirt road in front of a stone house.
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# 这幅画描绘了一只穿着蓝色长大衣和褐色西装的小兔子站在一条蜿蜒的农村小路上。背景中有一个古老的石头房子，绿色山丘和花园，呈现出一个和谐的田园风

# %%
import requests
from time import perf_counter

import torch
from PIL import Image
from transformers import MllamaForConditionalGeneration, AutoProcessor,TextIteratorStreamer
from qwen_vl_utils import process_vision_info


model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
model_id = "unsloth/Llama-3.2-11B-Vision-Instruct"
model = MllamaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    attn_implementation="sdpa", #sdpa or flash_attention_2, no eager
    #attn_implementation="flash_attention_2", #sdpa or flash_attention_2, no eager
    device_map="cuda",
    #trust_remote_code=True,
)
processor = AutoProcessor.from_pretrained(model_id,min_pixels=256 * 28 * 28,max_pixels=1280 * 28 * 28)

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/0052a70beed5bf71b92610a43a52df6d286cd5f3/diffusers/rabbit.jpg"

messages = [
    {"role": "user", "content": [
        {"type": "image", "image": url},
        {"type": "text", "text": "请用一句话描述图片内容，请用中文回复。"}
    ]}
]


times=[]
start_time = perf_counter()


# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)

image_inputs, _ = process_vision_info(messages)

inputs = processor(
    text=[text],
    images=image_inputs,
    padding=True,
    return_tensors="pt",
).to("cuda")


# Inference: Generation of the output with TextStreamer
streamer = TextIteratorStreamer(processor, skip_prompt=True, skip_special_tokens=True)
# Use Thread to run generation in background
# Otherwise, the process is blocked until generation is complete
# and no streaming effect can be observed.
from threading import Thread
generation_kwargs = dict(**inputs, streamer=streamer, max_new_tokens=128)
thread = Thread(target=model.generate, kwargs=generation_kwargs)
thread.start()

generated_text = ""
for new_text in streamer:
    print(new_text,end="")
    times.append(perf_counter() - start_time)
    generated_text += new_text
    start_time = perf_counter()
print(generated_text)

print("times",times)
print("total cost:",sum(times))
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# This image depicts a charming scene of a rabbit standing on a dirt path in front of a picturesque cottage, surrounded by a serene landscape of rolling hills and wildflowers. The rabbit is attired in a stylish blue coat, brown vest, and tan pants, adding a touch of whimsy to the scene. In the background, a quaint stone cottage with a thatched roof and chimney stands amidst lush greenery, while the sky above is dotted with fluffy white clouds.This image depicts a charming scene of a rabbit standing on a dirt path in front of a picturesque cottage, surrounded by a serene landscape of rolling hills and wildflowers. The rabbit is attired in a stylish blue coat, brown vest, and tan pants, adding a touch of whimsy to the scene. In the background, a quaint stone cottage with a thatched roof and chimney stands amidst lush greenery, while the sky above is dotted with fluffy white clouds.
