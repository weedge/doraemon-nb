# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/achatbot_codec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install

# %%
# !cd /content && rm -rf achatbot && git clone https://github.com/ai-bot-pro/achatbot.git -b feat/tts

# %%
# %cd /content/achatbot

# %%
# !git submodule update --init --recursive

# %%
# !git checkout . && git pull origin feat/tts

# %%
# !bash scripts/pypi_achatbot.sh dev

# %%
# !pip install -q dist/achatbot-0.0.8.10.13-py3-none-any.whl[codec_xcodec2]

# %%
# !pip install -q dist/achatbot-0.0.8.10.13-py3-none-any.whl[codec_moshi_mimi]

# %%
# !pip install -q dist/achatbot-0.0.8.10.13-py3-none-any.whl[codec_transformers_mimi,codec_transformers_dac]

# %% [markdown]
# # download ckpt

# %%
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential

# %%
# !huggingface-cli download descript/dac_44khz --quie --local-dir /content/models/descript/dac_44khz
# Out:
# /content/models/descript/dac_44khz

# %%
# !huggingface-cli download descript/dac_16khz --quie --local-dir /content/models/descript/dac_16khz
# Out:
# /content/models/descript/dac_16khz

# %%
# !huggingface-cli download HKUSTAudio/xcodec2 --quie --local-dir /content/models/HKUSTAudio/xcodec2
# Out:
# /content/models/HKUSTAudio/xcodec2

# %%
# !huggingface-cli download kyutai/moshiko-pytorch-bf16 --quie --local-dir /content/models/kyutai/moshiko-pytorch-bf16
# Out:
# /content/models/kyutai/moshiko-pytorch-bf16

# %%
# !huggingface-cli download kyutai/mimi --quie --local-dir /content/models/kyutai/mimi
# Out:
# /content/models/kyutai/mimi

# %% [markdown]
# # test codec

# %%
from IPython.display import Audio
Audio("/content/achatbot/test/audio_files/asr_example_zh.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !CODEC_TAG=codec_xcodec2 CODEC_MODEL_DIR=/content/models/HKUSTAudio/xcodec2 \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-02-17 03:37:10,331 - chat-bot - INFO - /usr/local/lib/python3.11/dist-packages/torchao/quantization/GPTQ.py:43 - <module> - lm_eval is not installed, GPTQ may not be usable
# 2025-02-17 03:37:10,386 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:114 - _find_ffmpeg_extension - Loading FFmpeg6
# 2025-02-17 03:37:10,394 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:120 - _find_ffmpeg_extension - Failed to load FFmpeg6 extension.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py", line 116, in _find_ffmpeg_extension
# ...

# %%
from IPython.display import Audio
Audio("codec_xcodec2_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !CODEC_TAG=codec_moshi_mimi CODEC_MODEL_DIR=/content/models/kyutai/moshiko-pytorch-bf16 \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-02-17 03:39:25,341 - chat-bot - INFO - /content/achatbot/src/common/factory.py:69 - get_engine_by_tag - use codec_moshi_mimi engine
# 2025-02-17 03:39:25,341 - chat-bot - INFO - /content/achatbot/src/common/factory.py:34 - get_instance - class: <class 'src.modules.codec.audio.moshi_mimi.MoshiMimiCodec'> args: {'model_dir': '/content/models/kyutai/moshiko-pytorch-bf16', 'device': None}
# 2025-02-17 03:39:25,362 - chat-bot - INFO - /content/achatbot/src/modules/codec/audio/moshi_mimi.py:31 - __init__ - CodecArgs: model_dir='/content/models/kyutai/moshiko-pytorch-bf16' device='cuda'
# ...

# %%
from IPython.display import Audio
Audio("codec_moshi_mimi_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !CODEC_TAG=codec_transformers_mimi CODEC_MODEL_DIR=/content/models/kyutai/mimi \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-02-17 03:39:44,847 - chat-bot - INFO - /usr/local/lib/python3.11/dist-packages/torchao/quantization/GPTQ.py:43 - <module> - lm_eval is not installed, GPTQ may not be usable
# 2025-02-17 03:39:45,241 - chat-bot - INFO - /content/achatbot/src/common/factory.py:69 - get_engine_by_tag - use codec_transformers_mimi engine
# 2025-02-17 03:39:45,241 - chat-bot - INFO - /content/achatbot/src/common/factory.py:34 - get_instance - class: <class 'src.modules.codec.audio.transformers_mimi.TransformersMimiCodec'> args: {'model_dir': '/content/models/kyutai/mimi', 'device': None}
# ...

# %%
from IPython.display import Audio
Audio("codec_transformers_mimi_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !CODEC_TAG=codec_transformers_dac CODEC_MODEL_DIR=/content/models/descript/dac_16khz \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-02-17 03:39:59,733 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:114 - _find_ffmpeg_extension - Loading FFmpeg6
# 2025-02-17 03:39:59,747 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:120 - _find_ffmpeg_extension - Failed to load FFmpeg6 extension.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py", line 116, in _find_ffmpeg_extension
#     ext = _find_versionsed_ffmpeg_extension(ffmpeg_ver)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !CODEC_TAG=codec_transformers_dac CODEC_MODEL_DIR=/content/models/descript/dac_44khz \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-02-17 03:40:16,007 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:114 - _find_ffmpeg_extension - Loading FFmpeg6
# 2025-02-17 03:40:16,008 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:120 - _find_ffmpeg_extension - Failed to load FFmpeg6 extension.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py", line 116, in _find_ffmpeg_extension
#     ext = _find_versionsed_ffmpeg_extension(ffmpeg_ver)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
from IPython.display import Audio
Audio("codec_transformers_dac_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
