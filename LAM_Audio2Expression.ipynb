# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/LAM_Audio2Expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/LAM_Audio2Expression && git clone https://github.com/weedge/LAM_Audio2Expression.git
# Out:
# Cloning into 'LAM_Audio2Expression'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 98 (delta 24), reused 86 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 5.51 MiB | 7.39 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# %cd /content/LAM_Audio2Expression
# Out:
# /content/LAM_Audio2Expression

# %%
# !pip install spleeter==2.4.2 opencv_python_headless gradio omegaconf addict==2.4.0 yapf==0.40.1 librosa termcolor numpy==1.24.3

# %%
# !pip install wheels/gradio_gaussian_render-0.0.3-py3-none-any.whl
# Out:
# Processing ./wheels/gradio_gaussian_render-0.0.3-py3-none-any.whl
# ...

# %%
# !pip list | grep -E "torch|gradio"
# Out:
# gradio                                5.25.2
# gradio_client                         1.8.0
# gradio_gaussian_render                0.0.3
# torch                                 2.6.0+cu124
# torchao                               0.10.0
# torchaudio                            2.6.0+cu124
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.21.0+cu124

# %% [markdown]
# # download

# %%
# %cd /content/LAM_Audio2Expression
# Out:
# /content/LAM_Audio2Expression

# %%
# !huggingface-cli download 3DAIGC/LAM_audio2exp --local-dir /content/LAM_Audio2Expression/
# Out:
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]Downloading 'LAM_audio2exp_streaming.tar' to '/content/LAM_Audio2Expression/.cache/huggingface/download/o0S-c6zjkluMpxZRzHxvu4G9aD0=.0877f419b1b7b6856479b743b71625ad478f97434404e91288f9f0d6d516b97a.incomplete'
# ...
#
# LAM_audio2exp_streaming.tar:   0% 0.00/373M [00:00<?, ?B/s]
#
# LAM_audio2exp_assets.tar:   0% 0.00/32.8M [00:00<?, ?B/s]Downloading 'README.md' to '/content/LAM_Audio2Expression/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.7b95401dc46245ac339fc25059d4a56d90b4cde5.incomplete'
# ...
#
# LAM_audio2exp_streaming.tar:   3% 10.5M/373M [00:00<00:05, 72.3MB/s]
#
# LAM_audio2exp_assets.tar:  32% 10.5M/32.8M [00:00<00:00, 70.8MB/s]
#
#
# README.md: 100% 31.0/31.0 [00:00<00:00, 101kB/s]
# Download complete. Moving file to /content/LAM_Audio2Expression/README.md
#
#
#
# .gitattributes: 0.00B [00:00, ?B/s]
# .gitattributes: 1.52kB [00:00, 2.73MB/s]
# Download complete. Moving file to /content/LAM_Audio2Expression/.gitattributes
# ...

# %%
# !tar -xzvf LAM_audio2exp_assets.tar && rm -f LAM_audio2exp_assets.tar
# !tar -xzvf LAM_audio2exp_streaming.tar && rm -f LAM_audio2exp_streaming.tar
# Out:
# assets/
# assets/images/
# assets/images/logo.jpeg
# assets/images/snapshot.png
# assets/images/teaser.jpg
# assets/sample_audio/
# assets/sample_audio/BarackObama_english.wav
# assets/sample_audio/FangXiao_japanese.wav
# assets/sample_audio/HillaryClinton_english.wav
# assets/sample_audio/LiBai_TTS_chinese.wav
# assets/sample_audio/LinJing_TTS_chinese.wav
# assets/sample_audio/Nangyanwen_chinese.wav
# assets/sample_audio/XitongShi_japanese.wav
# assets/sample_input/
# assets/sample_input/barbara.jpg
# assets/sample_input/james.png
# assets/sample_input/messi.png
# assets/sample_input/status.png
# assets/sample_input/vfhq_case1.png
# assets/sample_lam/
# assets/sample_lam/barbara/
# assets/sample_lam/barbara/arkitWithBSData/
# assets/sample_lam/barbara/arkitWithBSData/.DS_Store
# assets/sample_lam/barbara/arkitWithBSData/animation.glb
# assets/sample_lam/barbara/arkitWithBSData/bsData.json
# assets/sample_lam/barbara/arkitWithBSData/offset.ply
# ...

# %% [markdown]
# # audio2expression

# %%
# %cd /content/LAM_Audio2Expression
# Out:
# /content/LAM_Audio2Expression

# %%
# !python app_lam_audio2exp.py

# %%
from IPython.display import Audio
Audio("./assets/sample_audio/BarackObama_english.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python inference.py --config-file configs/lam_audio2exp_config_streaming.py \
  --options save_path=exp/audio2exp save_json_path=./BarackObama_english_bsData.json  \
  weight=pretrained_models/lam_audio2exp_streaming.tar \
  audio_input=./assets/sample_audio/BarackObama_english.wav
# Out:
# 2025-06-27 03:58:27.747670: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-27 03:58:27.804833: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-27 03:58:28.807463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2025-06-27 03:58:31,396 INFO infer.py line 51 21466] => Loading config ...
# [2025-06-27 03:58:31,396 INFO infer.py line 58 21466] => Building model ...
# [2025-06-27 03:58:34,011 INFO infer.py line 66 21466] Num params: 97912596
# [2025-06-27 03:58:34,348 INFO infer.py line 73 21466] Loading weight at: pretrained_models/lam_audio2exp_streaming.tar
# ...
