# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/achatbot_llasa_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ai-bot-pro/achatbot.git

# %%
# %cd /content/achatbot
# Out:
# /content/achatbot

# %%
# !bash -x scripts/pypi_achatbot.sh dev

# %%
# !pip install -q dist/achatbot-0.0.8.6-py3-none-any.whl[tts_llasa]

# %% [markdown]
# # download ckpt

# %%
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential

# %%
# !huggingface-cli download HKUSTAudio/xcodec2 --quiet --local-dir models/HKUSTAudio/xcodec2
# Out:
# /content/achatbot/models/HKUSTAudio/xcodec2

# %%
# !huggingface-cli download HKUSTAudio/Llasa-1B --quiet --local-dir models/HKUSTAudio/Llasa-1B
# Out:
# /content/achatbot/models/HKUSTAudio/Llasa-1B

# %% [markdown]
# # test

# %%
# !python -m unittest test.modules.speech.tts.test_llasa.TestLlasaTTS.test_get_voices
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-29 23:45:38,237 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:15 - <module> - pydot initializing
# 2025-01-29 23:45:38,237 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:16 - <module> - pydot 3.0.4
# 2025-01-29 23:45:38,294 - pydot.dot_parser - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/dot_parser.py:43 - <module> - pydot dot_parser module initializing
# 2025-01-29 23:45:38,295 - pydot.core - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/core.py:20 - <module> - pydot core module initializing
# ...

# %%
# !python -m unittest test.modules.speech.tts.test_llasa.TestLlasaTTS.test_set_voice
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-29 23:47:30,947 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:15 - <module> - pydot initializing
# 2025-01-29 23:47:30,947 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:16 - <module> - pydot 3.0.4
# 2025-01-29 23:47:31,029 - pydot.dot_parser - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/dot_parser.py:43 - <module> - pydot dot_parser module initializing
# 2025-01-29 23:47:31,031 - pydot.core - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/core.py:20 - <module> - pydot core module initializing
# ...

# %%
# !python -m unittest test.modules.speech.tts.test_llasa.TestLlasaTTS.test_synthesize
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-30 00:55:29,575 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:15 - <module> - pydot initializing
# 2025-01-30 00:55:29,576 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:16 - <module> - pydot 3.0.4
# 2025-01-30 00:55:29,634 - pydot.dot_parser - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/dot_parser.py:43 - <module> - pydot dot_parser module initializing
# 2025-01-30 00:55:29,635 - pydot.core - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/core.py:20 - <module> - pydot core module initializing
# ...

# %%
from IPython.display import Audio
Audio("/content/achatbot/records/test_tts_llasa.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# ref audio
# !LLASA_REF_AUDIO_PATH=./test/audio_files/asr_example_zh.wav \
    LLASA_PROMPT_TEXT="欢迎大家来体验达摩院推出的语音识别模型。" \
    python -m unittest test.modules.speech.tts.test_llasa.TestLlasaTTS.test_synthesize
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-29 23:51:42,244 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:15 - <module> - pydot initializing
# 2025-01-29 23:51:42,244 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:16 - <module> - pydot 3.0.4
# 2025-01-29 23:51:42,327 - pydot.dot_parser - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/dot_parser.py:43 - <module> - pydot dot_parser module initializing
# 2025-01-29 23:51:42,329 - pydot.core - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/core.py:20 - <module> - pydot core module initializing
# ...

# %%
from IPython.display import Audio
Audio("/content/achatbot/records/test_tts_llasa.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # grpc

# %%
#!pip install -q "dist/achatbot-0.0.8.6-py3-none-any.whl[remote_grpc_tts_server]"
# !pip install -q dist/achatbot-0.0.8.6-py3-none-any.whl[grpc,soundfile,tts_llasa]

# %% [markdown]
# ## tts speaker with grpc

# %%
#!python -m src.cmd.grpc.speaker.server.serve

# %%
# !TTS_TAG=tts_llasa IS_SAVE=1 IS_RELOAD=1 python -m src.cmd.grpc.speaker.client
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-30 00:58:17,070 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:15 - <module> - pydot initializing
# 2025-01-30 00:58:17,071 - pydot - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/__init__.py:16 - <module> - pydot 3.0.4
# 2025-01-30 00:58:17,101 - pydot.dot_parser - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/dot_parser.py:43 - <module> - pydot dot_parser module initializing
# 2025-01-30 00:58:17,102 - pydot.core - DEBUG - /usr/local/lib/python3.11/dist-packages/pydot/core.py:20 - <module> - pydot core module initializing
# ...

# %%
from IPython.display import Audio
Audio("/content/achatbot/records/grpc_tts_llasa.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
