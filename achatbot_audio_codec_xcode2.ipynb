# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/achatbot_audio_codec_xcode2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # init

# %%
# !rm -rf /content/achatbot && git clone https://github.com/ai-bot-pro/achatbot.git
# Out:
# Cloning into 'achatbot'...
# remote: Enumerating objects: 8212, done.
# remote: Counting objects: 100% (384/384), done.
# remote: Compressing objects: 100% (258/258), done.
# remote: Total 8212 (delta 222), reused 246 (delta 120), pack-reused 7828 (from 2)
# Receiving objects: 100% (8212/8212), 10.96 MiB | 43.49 MiB/s, done.
# Resolving deltas: 100% (4917/4917), done.

# %%
# %cd /content/achatbot
# Out:
# /content/achatbot

# %%
# !bash scripts/pypi_achatbot.sh dev

# %% [markdown]
# # test

# %%
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential

# %% [markdown]
# ## test xcodec2

# %%
# !pip install -q "dist/achatbot-0.0.8.6-py3-none-any.whl[codec_xcodec2]"

# %%
# !huggingface-cli download HKUSTAudio/xcodec2 --quiet --local-dir ./models/HKUSTAudio/xcodec2
# Out:
# /content/achatbot/models/HKUSTAudio/xcodec2

# %%
# !CODEC_TAG=codec_xcodec2 CODEC_MODEL_DIR=./models/HKUSTAudio/xcodec2 \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_fields.py:132: UserWarning: Field "model_dir" in CodecArgs has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# 2025-01-25 14:06:30,255 - chat-bot - INFO - /usr/local/lib/python3.11/dist-packages/torchao/quantization/GPTQ.py:43 - <module> - lm_eval is not installed, GPTQ may not be usable
# 2025-01-25 14:06:30,319 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:114 - _find_ffmpeg_extension - Loading FFmpeg6
# 2025-01-25 14:06:30,326 - torio._extension.utils - DEBUG - /usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py:120 - _find_ffmpeg_extension - Failed to load FFmpeg6 extension.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torio/_extension/utils.py", line 116, in _find_ffmpeg_extension
# ...

# %%
from IPython.display import Audio
Audio("codec_xcodec2_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
