# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/apple_OpenELM_on_CPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !lscpu
# Out:
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         46 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  8
#   On-line CPU(s) list:   0-7
# Vendor ID:               GenuineIntel
#   Model name:            Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:          6
#     Model:               79
#     Thread(s) per core:  2
#     Core(s) per socket:  4
#     Socket(s):           1
#     Stepping:            0
#     BogoMIPS:            4399.99
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clf
#                          lush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_
#                          good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fm
#                          a cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hyp
#                          ervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsb
#                          ase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsa
#                          veopt arat md_clear arch_capabilities
# Virtualization features:
#   Hypervisor vendor:     KVM
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   128 KiB (4 instances)
#   L1i:                   128 KiB (4 instances)
#   L2:                    1 MiB (4 instances)
#   L3:                    55 MiB (1 instance)
# NUMA:
#   NUMA node(s):          1
#   NUMA node0 CPU(s):     0-7
# Vulnerabilities:
#   Gather data sampling:  Not affected
#   Itlb multihit:         Not affected
#   L1tf:                  Mitigation; PTE Inversion
#   Mds:                   Vulnerable; SMT Host state unknown
#   Meltdown:              Vulnerable
#   Mmio stale data:       Vulnerable
#   Retbleed:              Vulnerable
#   Spec rstack overflow:  Not affected
#   Spec store bypass:     Vulnerable
#   Spectre v1:            Vulnerable: __user pointer sanitization and usercopy barriers only; no swap
#                          gs barriers
#   Spectre v2:            Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBRS: Not affected
#   Srbds:                 Not affected
#   Tsx async abort:       Vulnerable

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            50Gi       738Mi        46Gi       1.0Mi       3.8Gi        49Gi
# Swap:             0B          0B          0B

# %%
# !wget https://huggingface.co/apple/OpenELM/raw/main/generate_openelm.py -O generate_openelm.py
# Out:
# --2024-04-27 13:15:46--  https://huggingface.co/apple/OpenELM/raw/main/generate_openelm.py
# Resolving huggingface.co (huggingface.co)... 65.8.178.93, 65.8.178.118, 65.8.178.12, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7453 (7.3K) [text/plain]
# Saving to: ‘generate_openelm.py’
#
# generate_openelm.py 100%[===================>]   7.28K  --.-KB/s    in 0s
#
# 2024-04-27 13:15:46 (2.60 GB/s) - ‘generate_openelm.py’ saved [7453/7453]

# %%
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $hf_token
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # generate

# %% [markdown]
# ### use `prompt_lookup_num_tokens=10` Text generation strategies
#
# - https://twitter.com/joao_gante/status/1747322413006643259
# - https://huggingface.co/docs/transformers/generation_strategies

# %%
# !python generate_openelm.py --model apple/OpenELM-270M --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.30k/1.30k [00:00<00:00, 7.00MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 47.6MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-270M:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 8.00MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-270M:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 1.09G/1.09G [00:08<00:00, 132MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 632kB/s]
# tokenizer_config.json: 100% 776/776 [00:00<00:00, 4.33MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 6.38MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 14.4MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.52MB/s]
# 2024-04-27 13:16:29.055299: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:16:29.055358: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:16:29.057169: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:16:30.274584: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a man named John. He was a farmer, and he had a wife named Mary. They were married for 20 years, and they had two children. One day, John's wife died, and the other died too.
# John's wife was very sick, and she was dying. She was in pain, and she was not able to work. Her husband was very sad, and he wanted to help her. So he went to his brother-in-law, who was also a farmer, and he asked him if he could come over and help.
# The brother-in-law said that he would be happy to do so, but he didn't want to go alone. So John went with his brother-in-law, and they went to the farm where John's wife was dying.
# They found her body, and they buried her. Then they took her clothes, and they put them in a box. They put her shoes, and they put her purse, and they put her hair. They put her clothes on her, and they put her shoes on her, and they put her purse on her.
# Then they put her hair in a p
#
#
# Generation took 17.15 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-270M-Instruct \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.30k/1.30k [00:00<00:00, 6.77MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 47.5MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-270M-Instruct:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 9.76MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-270M-Instruct:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 543M/543M [00:04<00:00, 134MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 700kB/s]
# 2024-04-27 13:16:58.659424: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:16:58.659485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:16:58.660838: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:16:59.902738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a man named John Smith. He had been born in the small town of Pine Bluff, Arkansas, and raised by his single mother, Mary Ann. John's family moved to California when he was young, settling in San Francisco where he attended high school. After graduating from high school, John enlisted in the U.S. Army as a machine gunner.
# John's first assignment took him to Germany, serving with the 1st Battalion, 12th Infantry Regiment. During this time, John learned German and quickly became fluent in the language. In fact, it took him only two months to learn all 3,000 words of the alphabet. John's love for learning led him to attend college at Stanford University, majoring in history. While attending school, John also served as a rifleman in the 1st Armored Division.
# After completing his undergraduate education, John returned to California to join the U.S. Navy. Upon his return to California, John married Mary Lou, a local homemaker. They raised three children: John Jr., Kathy, and Sharon. John enjoyed spending time with
#
#
# Generation took 16.16 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-450M \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.41k/1.41k [00:00<00:00, 7.14MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 47.0MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-450M:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 8.07MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-450M:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 1.83G/1.83G [00:30<00:00, 60.0MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 623kB/s]
# 2024-04-27 13:18:06.450390: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:18:06.450451: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:18:06.451862: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:18:07.670159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little girl who lived in the woods. She had a big heart and she loved to play with her friends. One day, she decided to go for a walk in the woods. As she walked, she saw a beautiful tree. It was so tall that it looked like a mountain. The tree was covered with leaves and flowers.
# The little girl thought that this tree was very pretty. She wanted to climb up to the tree and see what was inside. So, she went up to the tree and climbed up to the top. She was very excited when she saw that the tree was full of beautiful flowers. She also saw that the leaves were all different colors.
# She started to look around the tree and she noticed that there were many animals living in the tree. There were birds, bees, butterflies, and even some cats. The little girl was very happy when she saw all of these beautiful creatures.
# After she climbed up to the tree, she saw that there was a hole in the tree. She thought that this hole was where the animals would eat their food. She also thought that the animals would eat the leaves and flowers that were growing on the tree.
# The little girl was
#
#
# Generation took 28.63 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-450M-Instruct \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.41k/1.41k [00:00<00:00, 6.73MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 49.5MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-450M-Instruct:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 10.0MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-450M-Instruct:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 914M/914M [00:06<00:00, 136MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 609kB/s]
# 2024-04-27 13:18:49.639462: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:18:49.639527: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:18:49.640870: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:18:50.869998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little boy named Peter. His father, John, loved him dearly and wanted the very best for him. He taught Peter everything he knew about being a Christian, how to pray, and how to love others.
# One day, Peter's mother, Mary, came home from work. She saw her son standing in the doorway with a Bible in his hand. "Come in," she called out. "Peter, pick up your Bible and come sit down."
# Peter hesitated. "I don't really want to read my Bible right now," he said. "It's just sitting on the table next to my bed."
# "Don't worry," Mary assured him. "You can always take it out when you feel like reading."
# Peter sat down beside his mother's Bible. As the hours passed, Peter continued to study God's Word. One night, as he lay in bed, Mary heard Peter singing hymns of praise to God. Her heart melted. "Oh, Peter, what a beautiful voice! You must be so proud of your dad teaching you this wonderful faith!"
# The next morning, Mary took Peter to church. When they arrived,
#
#
# Generation took 28.05 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-1_1B \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.60k/1.60k [00:00<00:00, 7.92MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 42.0MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-1_1B:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 9.89MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-1_1B:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 4.32G/4.32G [00:35<00:00, 123MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 555kB/s]
# 2024-04-27 13:20:13.436842: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:20:13.436921: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:20:13.440048: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:20:14.851765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little girl who loved to read. She had a bookshelf full of books and she would spend hours reading them. One day, her mother came home from work and asked her what she had been reading. The little girl told her that she had been reading a book about a boy who lived in the woods. Her mother said that it sounded like a good book and so she bought it for her daughter.
# The next day, the little girl went to the library and checked out the book. She read it all the way through and then she put it back on the shelf. A few days later, her mother came home from work and asked her what she had been reading. The little girl told her that she had been reading a book about a boy who lived in the woods. Her mother said that it sounded like a good book and so she bought it for her daughter.
# The next day, the little girl went to the library and checked out the book. She read it all the way through and then she put it back on the shelf. A few days later, her mother came home from work and asked her what she had been reading. The little girl told her that she had been reading a book
#
#
# Generation took 39.02 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-1_1B-Instruct \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.60k/1.60k [00:00<00:00, 7.41MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 43.7MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-1_1B-Instruct:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 9.88MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-1_1B-Instruct:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100% 2.16G/2.16G [00:17<00:00, 121MB/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 609kB/s]
# 2024-04-27 13:21:34.358087: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:21:34.358144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:21:34.359592: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:21:35.595318: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little boy named Jack.
# Jack loved to read, and he especially loved books about pirates.
# One day Jack's mommy took him to the library to check out some pirate books.
# As Jack walked down the stacks, his eyes kept scanning for one particular book: Captain Blood and the Seven Seventies.
# The title intrigued Jack because it sounded like a really cool adventure story set in an exotic place called the "Seven Seventies."
# When Jack got home, his mommy told him all about Captain Blood and the Seven Seventies.
# "It's a great pirate book," Mommy said. "You'll love it!"
# Jack couldn't wait to read it!
# But first, Jack asked if Daddy could help him make a special Pirate Jack costume.
# Daddy agreed, and they spent a whole weekend sewing and crafting Jack's Pirate Jack Costume.
# The Pirate Jack Costume featured a red shirt with white trim, black pants, a green felt hat with a gold buckle, and a long sword with a wooden handle and silver hilt.
#
#
# Generation took 53.26 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-3B \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.77k/1.77k [00:00<00:00, 7.57MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 48.2MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-3B:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 10.1MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-3B:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json: 100% 24.2k/24.2k [00:00<00:00, 25.3MB/s]
# Downloading shards:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.98G [00:00<01:28, 56.1MB/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.98G [00:00<00:53, 92.7MB/s]
# model-00001-of-00003.safetensors:   1% 52.4M/4.98G [00:00<00:44, 110MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.98G [00:00<00:40, 121MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.98G [00:00<00:38, 127MB/s]
# model-00001-of-00003.safetensors:   2% 115M/4.98G [00:00<00:37, 131MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.98G [00:01<00:36, 133MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.98G [00:01<00:35, 135MB/s]
# model-00001-of-00003.safetensors:   4% 178M/4.98G [00:01<00:35, 136MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.98G [00:01<00:34, 137MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.98G [00:01<00:34, 138MB/s]
# model-00001-of-00003.safetensors:   5% 241M/4.98G [00:01<00:34, 138MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.98G [00:02<00:34, 139MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   6% 304M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   7% 325M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   7% 367M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.98G [00:02<00:33, 139MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.98G [00:03<00:33, 138MB/s]
# model-00001-of-00003.safetensors:   9% 430M/4.98G [00:03<00:32, 138MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.98G [00:03<00:32, 138MB/s]
# model-00001-of-00003.safetensors:   9% 472M/4.98G [00:03<00:32, 138MB/s]
# model-00001-of-00003.safetensors:  10% 493M/4.98G [00:03<00:32, 138MB/s]
# model-00001-of-00003.safetensors:  10% 514M/4.98G [00:03<00:32, 137MB/s]
# model-00001-of-00003.safetensors:  11% 535M/4.98G [00:03<00:32, 137MB/s]
# model-00001-of-00003.safetensors:  11% 556M/4.98G [00:04<00:32, 135MB/s]
# model-00001-of-00003.safetensors:  12% 577M/4.98G [00:04<00:32, 135MB/s]
# model-00001-of-00003.safetensors:  12% 598M/4.98G [00:04<00:32, 137MB/s]
# model-00001-of-00003.safetensors:  12% 619M/4.98G [00:04<00:31, 138MB/s]
# model-00001-of-00003.safetensors:  13% 640M/4.98G [00:04<00:31, 138MB/s]
# model-00001-of-00003.safetensors:  13% 661M/4.98G [00:04<00:31, 139MB/s]
# model-00001-of-00003.safetensors:  14% 682M/4.98G [00:05<00:30, 139MB/s]
# model-00001-of-00003.safetensors:  14% 703M/4.98G [00:05<00:30, 140MB/s]
# model-00001-of-00003.safetensors:  15% 724M/4.98G [00:05<00:31, 137MB/s]
# model-00001-of-00003.safetensors:  15% 744M/4.98G [00:05<00:30, 138MB/s]
# model-00001-of-00003.safetensors:  15% 765M/4.98G [00:05<00:30, 139MB/s]
# model-00001-of-00003.safetensors:  16% 786M/4.98G [00:05<00:30, 139MB/s]
# model-00001-of-00003.safetensors:  16% 807M/4.98G [00:05<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  17% 828M/4.98G [00:06<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  17% 849M/4.98G [00:06<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  17% 870M/4.98G [00:06<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  18% 891M/4.98G [00:06<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  18% 912M/4.98G [00:06<00:29, 140MB/s]
# model-00001-of-00003.safetensors:  19% 933M/4.98G [00:06<00:28, 140MB/s]
# model-00001-of-00003.safetensors:  19% 954M/4.98G [00:07<00:28, 140MB/s]
# model-00001-of-00003.safetensors:  20% 975M/4.98G [00:07<00:28, 139MB/s]
# model-00001-of-00003.safetensors:  20% 996M/4.98G [00:07<00:28, 139MB/s]
# model-00001-of-00003.safetensors:  20% 1.02G/4.98G [00:07<00:28, 139MB/s]
# model-00001-of-00003.safetensors:  21% 1.04G/4.98G [00:07<00:29, 135MB/s]
# model-00001-of-00003.safetensors:  21% 1.06G/4.98G [00:07<00:29, 133MB/s]
# model-00001-of-00003.safetensors:  22% 1.08G/4.98G [00:07<00:29, 134MB/s]
# model-00001-of-00003.safetensors:  22% 1.10G/4.98G [00:08<00:28, 134MB/s]
# model-00001-of-00003.safetensors:  23% 1.12G/4.98G [00:08<00:28, 135MB/s]
# model-00001-of-00003.safetensors:  23% 1.14G/4.98G [00:08<00:28, 133MB/s]
# model-00001-of-00003.safetensors:  23% 1.16G/4.98G [00:08<00:28, 133MB/s]
# model-00001-of-00003.safetensors:  24% 1.18G/4.98G [00:08<00:28, 134MB/s]
# model-00001-of-00003.safetensors:  24% 1.21G/4.98G [00:08<00:27, 135MB/s]
# model-00001-of-00003.safetensors:  25% 1.23G/4.98G [00:09<00:27, 136MB/s]
# model-00001-of-00003.safetensors:  25% 1.25G/4.98G [00:09<00:27, 137MB/s]
# model-00001-of-00003.safetensors:  25% 1.27G/4.98G [00:09<00:26, 138MB/s]
# model-00001-of-00003.safetensors:  26% 1.29G/4.98G [00:09<00:26, 139MB/s]
# model-00001-of-00003.safetensors:  26% 1.31G/4.98G [00:09<00:26, 139MB/s]
# model-00001-of-00003.safetensors:  27% 1.33G/4.98G [00:09<00:26, 139MB/s]
# model-00001-of-00003.safetensors:  27% 1.35G/4.98G [00:09<00:26, 139MB/s]
# model-00001-of-00003.safetensors:  28% 1.37G/4.98G [00:10<00:25, 139MB/s]
# model-00001-of-00003.safetensors:  28% 1.39G/4.98G [00:10<00:25, 139MB/s]
# model-00001-of-00003.safetensors:  28% 1.42G/4.98G [00:10<00:25, 140MB/s]
# model-00001-of-00003.safetensors:  29% 1.44G/4.98G [00:10<00:26, 136MB/s]
# model-00001-of-00003.safetensors:  29% 1.46G/4.98G [00:10<00:27, 129MB/s]
# model-00001-of-00003.safetensors:  30% 1.48G/4.98G [00:10<00:27, 128MB/s]
# model-00001-of-00003.safetensors:  30% 1.50G/4.98G [00:11<00:26, 132MB/s]
# model-00001-of-00003.safetensors:  31% 1.52G/4.98G [00:11<00:25, 134MB/s]
# model-00001-of-00003.safetensors:  31% 1.54G/4.98G [00:11<00:25, 136MB/s]
# model-00001-of-00003.safetensors:  31% 1.56G/4.98G [00:11<00:24, 137MB/s]
# model-00001-of-00003.safetensors:  32% 1.58G/4.98G [00:11<00:28, 120MB/s]
# model-00001-of-00003.safetensors:  32% 1.60G/4.98G [00:11<00:32, 104MB/s]
# model-00001-of-00003.safetensors:  33% 1.63G/4.98G [00:12<00:33, 101MB/s]
# model-00001-of-00003.safetensors:  33% 1.65G/4.98G [00:12<00:32, 103MB/s]
# model-00001-of-00003.safetensors:  33% 1.67G/4.98G [00:12<00:32, 103MB/s]
# model-00001-of-00003.safetensors:  34% 1.69G/4.98G [00:12<00:30, 107MB/s]
# model-00001-of-00003.safetensors:  34% 1.71G/4.98G [00:13<00:31, 104MB/s]
# model-00001-of-00003.safetensors:  35% 1.73G/4.98G [00:13<00:31, 103MB/s]
# model-00001-of-00003.safetensors:  35% 1.75G/4.98G [00:13<00:30, 107MB/s]
# model-00001-of-00003.safetensors:  36% 1.77G/4.98G [00:13<00:29, 109MB/s]
# model-00001-of-00003.safetensors:  36% 1.79G/4.98G [00:13<00:29, 108MB/s]
# model-00001-of-00003.safetensors:  36% 1.81G/4.98G [00:13<00:29, 108MB/s]
# model-00001-of-00003.safetensors:  37% 1.84G/4.98G [00:14<00:28, 109MB/s]
# model-00001-of-00003.safetensors:  37% 1.86G/4.98G [00:14<00:41, 76.1MB/s]
# model-00001-of-00003.safetensors:  38% 1.88G/4.98G [00:14<00:35, 87.8MB/s]
# model-00001-of-00003.safetensors:  38% 1.90G/4.98G [00:14<00:31, 97.2MB/s]
# model-00001-of-00003.safetensors:  39% 1.92G/4.98G [00:15<00:30, 101MB/s]
# model-00001-of-00003.safetensors:  39% 1.94G/4.98G [00:15<00:27, 110MB/s]
# model-00001-of-00003.safetensors:  39% 1.96G/4.98G [00:15<00:26, 116MB/s]
# model-00001-of-00003.safetensors:  40% 1.98G/4.98G [00:15<00:24, 122MB/s]
# model-00001-of-00003.safetensors:  40% 2.00G/4.98G [00:15<00:23, 126MB/s]
# model-00001-of-00003.safetensors:  41% 2.02G/4.98G [00:15<00:22, 129MB/s]
# model-00001-of-00003.safetensors:  41% 2.04G/4.98G [00:16<00:22, 132MB/s]
# model-00001-of-00003.safetensors:  41% 2.07G/4.98G [00:16<00:21, 134MB/s]
# model-00001-of-00003.safetensors:  42% 2.09G/4.98G [00:16<00:21, 136MB/s]
# model-00001-of-00003.safetensors:  42% 2.11G/4.98G [00:16<00:21, 137MB/s]
# model-00001-of-00003.safetensors:  43% 2.13G/4.98G [00:16<00:20, 138MB/s]
# model-00001-of-00003.safetensors:  43% 2.15G/4.98G [00:16<00:20, 138MB/s]
# model-00001-of-00003.safetensors:  44% 2.17G/4.98G [00:16<00:20, 139MB/s]
# model-00001-of-00003.safetensors:  44% 2.19G/4.98G [00:17<00:20, 139MB/s]
# model-00001-of-00003.safetensors:  44% 2.21G/4.98G [00:17<00:19, 139MB/s]
# model-00001-of-00003.safetensors:  45% 2.23G/4.98G [00:17<00:19, 139MB/s]
# model-00001-of-00003.safetensors:  45% 2.25G/4.98G [00:17<00:19, 139MB/s]
# model-00001-of-00003.safetensors:  46% 2.28G/4.98G [00:17<00:19, 139MB/s]
# model-00001-of-00003.safetensors:  46% 2.30G/4.98G [00:17<00:19, 137MB/s]
# model-00001-of-00003.safetensors:  47% 2.32G/4.98G [00:18<00:19, 136MB/s]
# model-00001-of-00003.safetensors:  47% 2.34G/4.98G [00:18<00:19, 135MB/s]
# model-00001-of-00003.safetensors:  47% 2.36G/4.98G [00:18<00:19, 135MB/s]
# model-00001-of-00003.safetensors:  48% 2.38G/4.98G [00:18<00:20, 129MB/s]
# model-00001-of-00003.safetensors:  48% 2.40G/4.98G [00:18<00:20, 127MB/s]
# model-00001-of-00003.safetensors:  49% 2.42G/4.98G [00:18<00:20, 126MB/s]
B/s]
# model-00001-of-00003.safetensors:  63% 3.14G/4.98G [00:24<00:13, 132MB/s]
# model-00001-of-00003.safetensors:  63% 3.16G/4.98G [00:24<00:13, 133MB/s]
# model-00001-of-00003.safetensors:  64% 3.18G/4.98G [00:24<00:13, 134MB/s]
# model-00001-of-00003.safetensors:  64% 3.20G/4.98G [00:25<00:13, 135MB/s]
# model-00001-of-00003.safetensors:  65% 3.22G/4.98G [00:25<00:13, 135MB/s]
# model-00001-of-00003.safetensors:  65% 3.24G/4.98G [00:25<00:14, 119MB/s]
# model-00001-of-00003.safetensors:  65% 3.26G/4.98G [00:25<00:15, 110MB/s]
# model-00001-of-00003.safetensors:  66% 3.28G/4.98G [00:25<00:14, 117MB/s]
# model-00001-of-00003.safetensors:  66% 3.30G/4.98G [00:26<00:16, 101MB/s]
# model-00001-of-00003.safetensors:  67% 3.32G/4.98G [00:26<00:15, 105MB/s]
# model-00001-of-00003.safetensors:  67% 3.34G/4.98G [00:26<00:14, 111MB/s]
# model-00001-of-00003.safetensors:  68% 3.37G/4.98G [00:26<00:16, 101MB/s]
# model-00001-of-00003.safetensors:  68% 3.39G/4.98G [00:26<00:15, 105MB/s]
# model-00001-of-00003.safetensors:  68% 3.41G/4.98G [00:27<00:16, 95.0MB/s]
# model-00001-of-00003.safetensors:  69% 3.43G/4.98G [00:27<00:14, 104MB/s]
# model-00001-of-00003.safetensors:  69% 3.45G/4.98G [00:27<00:13, 112MB/s]
# model-00001-of-00003.safetensors:  70% 3.47G/4.98G [00:27<00:12, 118MB/s]
# model-00001-of-00003.safetensors:  70% 3.49G/4.98G [00:27<00:15, 99.2MB/s]
# model-00001-of-00003.safetensors:  70% 3.51G/4.98G [00:28<00:16, 91.5MB/s]
# model-00001-of-00003.safetensors:  71% 3.52G/4.98G [00:28<00:16, 86.3MB/s]
# model-00001-of-00003.safetensors:  71% 3.54G/4.98G [00:28<00:15, 95.3MB/s]
# model-00001-of-00003.safetensors:  71% 3.55G/4.98G [00:28<00:15, 93.8MB/s]
# model-00001-of-00003.safetensors:  72% 3.57G/4.98G [00:28<00:16, 85.9MB/s]
# model-00001-of-00003.safetensors:  72% 3.58G/4.98G [00:28<00:16, 87.4MB/s]
# model-00001-of-00003.safetensors:  72% 3.59G/4.98G [00:28<00:15, 89.5MB/s]
# model-00001-of-00003.safetensors:  72% 3.61G/4.98G [00:29<00:15, 90.1MB/s]
# model-00001-of-00003.safetensors:  73% 3.63G/4.98G [00:29<00:14, 95.2MB/s]
# model-00001-of-00003.safetensors:  73% 3.65G/4.98G [00:29<00:13, 97.2MB/s]
# model-00001-of-00003.safetensors:  74% 3.67G/4.98G [00:29<00:12, 107MB/s]
# model-00001-of-00003.safetensors:  74% 3.69G/4.98G [00:29<00:11, 115MB/s]
# model-00001-of-00003.safetensors:  74% 3.71G/4.98G [00:30<00:10, 121MB/s]
# model-00001-of-00003.safetensors:  75% 3.73G/4.98G [00:30<00:09, 125MB/s]
# model-00001-of-00003.safetensors:  75% 3.75G/4.98G [00:30<00:09, 128MB/s]
# model-00001-of-00003.safetensors:  76% 3.77G/4.98G [00:30<00:09, 131MB/s]
# model-00001-of-00003.safetensors:  76% 3.80G/4.98G [00:30<00:08, 133MB/s]
# model-00001-of-00003.safetensors:  77% 3.82G/4.98G [00:30<00:08, 134MB/s]
# model-00001-of-00003.safetensors:  77% 3.84G/4.98G [00:30<00:08, 134MB/s]
# model-00001-of-00003.safetensors:  77% 3.86G/4.98G [00:31<00:08, 135MB/s]
# model-00001-of-00003.safetensors:  78% 3.88G/4.98G [00:31<00:08, 135MB/s]
# model-00001-of-00003.safetensors:  78% 3.90G/4.98G [00:31<00:07, 136MB/s]
# model-00001-of-00003.safetensors:  79% 3.92G/4.98G [00:31<00:07, 136MB/s]
# model-00001-of-00003.safetensors:  79% 3.94G/4.98G [00:31<00:07, 137MB/s]
# model-00001-of-00003.safetensors:  80% 3.96G/4.98G [00:31<00:07, 137MB/s]
# model-00001-of-00003.safetensors:  80% 3.98G/4.98G [00:32<00:07, 137MB/s]
# model-00001-of-00003.safetensors:  80% 4.01G/4.98G [00:32<00:07, 137MB/s]
# model-00001-of-00003.safetensors:  81% 4.03G/4.98G [00:32<00:07, 136MB/s]
# model-00001-of-00003.safetensors:  81% 4.05G/4.98G [00:32<00:06, 136MB/s]
# model-00001-of-00003.safetensors:  82% 4.07G/4.98G [00:32<00:06, 136MB/s]
# model-00001-of-00003.safetensors:  82% 4.09G/4.98G [00:32<00:06, 136MB/s]
# model-00001-of-00003.safetensors:  82% 4.11G/4.98G [00:32<00:06, 133MB/s]
# model-00001-of-00003.safetensors:  83% 4.13G/4.98G [00:33<00:06, 130MB/s]
# model-00001-of-00003.safetensors:  83% 4.15G/4.98G [00:33<00:06, 131MB/s]
# model-00001-of-00003.safetensors:  84% 4.17G/4.98G [00:33<00:06, 129MB/s]
# model-00001-of-00003.safetensors:  84% 4.19G/4.98G [00:33<00:06, 128MB/s]
# model-00001-of-00003.safetensors:  85% 4.22G/4.98G [00:33<00:06, 126MB/s]
# model-00001-of-00003.safetensors:  85% 4.24G/4.98G [00:33<00:05, 129MB/s]
# model-00001-of-00003.safetensors:  85% 4.26G/4.98G [00:34<00:05, 131MB/s]
# model-00001-of-00003.safetensors:  86% 4.28G/4.98G [00:34<00:05, 133MB/s]
# model-00001-of-00003.safetensors:  86% 4.30G/4.98G [00:34<00:05, 134MB/s]
# model-00001-of-00003.safetensors:  87% 4.32G/4.98G [00:34<00:04, 135MB/s]
# model-00001-of-00003.safetensors:  87% 4.34G/4.98G [00:34<00:04, 135MB/s]
# model-00001-of-00003.safetensors:  88% 4.36G/4.98G [00:34<00:04, 136MB/s]
# model-00001-of-00003.safetensors:  88% 4.38G/4.98G [00:35<00:04, 136MB/s]
# model-00001-of-00003.safetensors:  88% 4.40G/4.98G [00:35<00:04, 137MB/s]
# model-00001-of-00003.safetensors:  89% 4.42G/4.98G [00:35<00:04, 135MB/s]
# model-00001-of-00003.safetensors:  89% 4.45G/4.98G [00:35<00:04, 133MB/s]
# model-00001-of-00003.safetensors:  90% 4.47G/4.98G [00:35<00:03, 134MB/s]
# model-00001-of-00003.safetensors:  90% 4.49G/4.98G [00:35<00:03, 133MB/s]
# model-00001-of-00003.safetensors:  90% 4.51G/4.98G [00:35<00:03, 134MB/s]
# model-00001-of-00003.safetensors:  91% 4.53G/4.98G [00:36<00:03, 135MB/s]
# model-00001-of-00003.safetensors:  91% 4.55G/4.98G [00:36<00:03, 135MB/s]
# model-00001-of-00003.safetensors:  92% 4.57G/4.98G [00:36<00:03, 136MB/s]
# model-00001-of-00003.safetensors:  92% 4.59G/4.98G [00:36<00:02, 136MB/s]
# model-00001-of-00003.safetensors:  93% 4.61G/4.98G [00:36<00:02, 136MB/s]
# model-00001-of-00003.safetensors:  93% 4.63G/4.98G [00:36<00:02, 136MB/s]
# model-00001-of-00003.safetensors:  93% 4.66G/4.98G [00:37<00:02, 137MB/s]
# model-00001-of-00003.safetensors:  94% 4.68G/4.98G [00:37<00:02, 137MB/s]
# model-00001-of-00003.safetensors:  94% 4.70G/4.98G [00:37<00:02, 136MB/s]
# model-00001-of-00003.safetensors:  95% 4.72G/4.98G [00:37<00:01, 136MB/s]
# model-00001-of-00003.safetensors:  95% 4.74G/4.98G [00:37<00:02, 93.1MB/s]
# model-00001-of-00003.safetensors:  96% 4.76G/4.98G [00:38<00:02, 98.2MB/s]
# model-00001-of-00003.safetensors:  96% 4.78G/4.98G [00:38<00:01, 104MB/s]
# model-00001-of-00003.safetensors:  96% 4.80G/4.98G [00:38<00:01, 109MB/s]
# model-00001-of-00003.safetensors:  97% 4.82G/4.98G [00:38<00:01, 113MB/s]
# model-00001-of-00003.safetensors:  97% 4.84G/4.98G [00:38<00:01, 117MB/s]
# model-00001-of-00003.safetensors:  98% 4.87G/4.98G [00:38<00:01, 114MB/s]
# model-00001-of-00003.safetensors:  98% 4.89G/4.98G [00:39<00:00, 120MB/s]
# model-00001-of-00003.safetensors:  98% 4.91G/4.98G [00:39<00:00, 125MB/s]
# model-00001-of-00003.safetensors:  99% 4.93G/4.98G [00:39<00:00, 128MB/s]
# model-00001-of-00003.safetensors:  99% 4.95G/4.98G [00:39<00:00, 131MB/s]
# model-00001-of-00003.safetensors: 100% 4.98G/4.98G [00:39<00:00, 125MB/s]
# Downloading shards:  33% 1/3 [00:40<01:20, 40.08s/it]
# model-00002-of-00003.safetensors:   0% 0.00/4.90G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 21.0M/4.90G [00:00<00:36, 136MB/s]
# model-00002-of-00003.safetensors:   1% 41.9M/4.90G [00:00<00:35, 136MB/s]
# model-00002-of-00003.safetensors:   1% 62.9M/4.90G [00:00<00:36, 133MB/s]
# model-00002-of-00003.safetensors:   2% 83.9M/4.90G [00:00<00:36, 130MB/s]
# model-00002-of-00003.safetensors:   2% 105M/4.90G [00:00<00:36, 133MB/s]
# model-00002-of-00003.safetensors:   3% 126M/4.90G [00:00<00:35, 134MB/s]
# model-00002-of-00003.safetensors:   3% 147M/4.90G [00:01<00:35, 134MB/s]
# model-00002-of-00003.safetensors:   3% 168M/4.90G [00:01<00:35, 135MB/s]
# model-00002-of-00003.safetensors:   4% 189M/4.90G [00:01<00:34, 136MB/s]
# model-00002-of-00003.safetensors:   4% 210M/4.90G [00:01<00:34, 136MB/s]
# model-00002-of-00003.safetensors:   5% 231M/4.90G [00:01<00:34, 136MB/s]
# model-00002-of-00003.safetensors:   5% 252M/4.90G [00:01<00:34, 134MB/s]
# model-00002-of-00003.safetensors:   6% 273M/4.90G [00:02<00:34, 135MB/s]
# model-00002-of-00003.safetensors:   6% 294M/4.90G [00:02<00:34, 133MB/s]
# model-00002-of-00003.safetensors:   6% 315M/4.90G [00:02<00:34, 135MB/s]
# model-00002-of-00003.safetensors:   7% 336M/4.90G [00:02<00:33, 136MB/s]
# model-00002-of-00003.safetensors:   7% 357M/4.90G [00:02<00:33, 136MB/s]
# model-00002-of-00003.safetensors:   8% 377M/4.90G [00:02<00:33, 136MB/s]
# model-00002-of-00003.safetensors:   8% 398M/4.90G [00:02<00:33, 137MB/s]
# model-00002-of-00003.safetensors:   9% 419M/4.90G [00:03<00:32, 137MB/s]
# model-00002-of-00003.safetensors:   9% 440M/4.90G [00:03<00:32, 136MB/s]
# model-00002-of-00003.safetensors:   9% 461M/4.90G [00:03<00:33, 134MB/s]
# model-00002-of-00003.safetensors:  10% 482M/4.90G [00:03<00:32, 135MB/s]
# model-00002-of-00003.safetensors:  10% 503M/4.90G [00:03<00:32, 134MB/s]
# model-00002-of-00003.safetensors:  11% 524M/4.90G [00:03<00:32, 133MB/s]
# model-00002-of-00003.safetensors:  11% 545M/4.90G [00:04<00:32, 134MB/s]
# model-00002-of-00003.safetensors:  12% 566M/4.90G [00:04<00:32, 133MB/s]
# model-00002-of-00003.safetensors:  12% 587M/4.90G [00:04<00:33, 127MB/s]
# model-00002-of-00003.safetensors:  12% 608M/4.90G [00:04<00:33, 128MB/s]
# model-00002-of-00003.safetensors:  13% 629M/4.90G [00:04<00:33, 126MB/s]
# model-00002-of-00003.safetensors:  13% 650M/4.90G [00:04<00:34, 123MB/s]
# model-00002-of-00003.safetensors:  14% 671M/4.90G [00:05<00:34, 123MB/s]
# model-00002-of-00003.safetensors:  14% 692M/4.90G [00:05<00:34, 122MB/s]
# model-00002-of-00003.safetensors:  15% 713M/4.90G [00:05<00:33, 126MB/s]
# model-00002-of-00003.safetensors:  15% 734M/4.90G [00:05<00:32, 129MB/s]
# model-00002-of-00003.safetensors:  15% 755M/4.90G [00:05<00:31, 132MB/s]
# model-00002-of-00003.safetensors:  16% 776M/4.90G [00:05<00:30, 133MB/s]
# model-00002-of-00003.safetensors:  16% 797M/4.90G [00:06<00:30, 134MB/s]
# model-00002-of-00003.safetensors:  17% 818M/4.90G [00:06<00:30, 135MB/s]
# model-00002-of-00003.safetensors:  17% 839M/4.90G [00:06<00:29, 136MB/s]
# model-00002-of-00003.safetensors:  18% 860M/4.90G [00:06<00:29, 136MB/s]
# model-00002-of-00003.safetensors:  18% 881M/4.90G [00:06<00:29, 137MB/s]
# model-00002-of-00003.safetensors:  18% 902M/4.90G [00:06<00:29, 137MB/s]
# model-00002-of-00003.safetensors:  19% 923M/4.90G [00:06<00:29, 137MB/s]
# model-00002-of-00003.safetensors:  19% 944M/4.90G [00:07<00:29, 134MB/s]
# model-00002-of-00003.safetensors:  20% 965M/4.90G [00:07<00:29, 135MB/s]
# model-00002-of-00003.safetensors:  20% 986M/4.90G [00:07<00:28, 136MB/s]
# model-00002-of-00003.safetensors:  21% 1.01G/4.90G [00:07<00:28, 136MB/s]
# model-00002-of-00003.safetensors:  21% 1.03G/4.90G [00:07<00:28, 136MB/s]
# model-00002-of-00003.safetensors:  21% 1.05G/4.90G [00:07<00:28, 137MB/s]
# model-00002-of-00003.safetensors:  22% 1.07G/4.90G [00:08<00:28, 137MB/s]
# model-00002-of-00003.safetensors:  22% 1.09G/4.90G [00:08<00:28, 135MB/s]
# model-00002-of-00003.safetensors:  23% 1.11G/4.90G [00:08<00:28, 134MB/s]
# model-00002-of-00003.safetensors:  23% 1.13G/4.90G [00:08<00:28, 134MB/s]
# model-00002-of-00003.safetensors:  24% 1.15G/4.90G [00:08<00:27, 135MB/s]
# model-00002-of-00003.safetensors:  24% 1.17G/4.90G [00:08<00:27, 134MB/s]
# model-00002-of-00003.safetensors:  24% 1.20G/4.90G [00:08<00:27, 135MB/s]
# model-00002-of-00003.safetensors:  25% 1.22G/4.90G [00:09<00:39, 94.0MB/s]
# model-00002-of-00003.safetensors:  25% 1.24G/4.90G [00:09<00:35, 103MB/s]
# model-00002-of-00003.safetensors:  26% 1.26G/4.90G [00:09<00:32, 111MB/s]
# model-00002-of-00003.safetensors:  26% 1.28G/4.90G [00:09<00:30, 117MB/s]
# model-00002-of-00003.safetensors:  27% 1.30G/4.90G [00:09<00:29, 123MB/s]
# model-00002-of-00003.safetensors:  27% 1.32G/4.90G [00:10<00:28, 127MB/s]
# model-00002-of-00003.safetensors:  27% 1.34G/4.90G [00:10<00:28, 127MB/s]
# model-00002-of-00003.safetensors:  28% 1.36G/4.90G [00:10<00:27, 128MB/s]
# model-00002-of-00003.safetensors:  28% 1.38G/4.90G [00:10<00:27, 127MB/s]
# model-00002-of-00003.safetensors:  29% 1.41G/4.90G [00:10<00:27, 126MB/s]
# model-00002-of-00003.safetensors:  29% 1.43G/4.90G [00:10<00:27, 125MB/s]
# model-00002-of-00003.safetensors:  30% 1.45G/4.90G [00:11<00:27, 124MB/s]
# model-00002-of-00003.safetensors:  30% 1.47G/4.90G [00:11<00:27, 125MB/s]
# model-00002-of-00003.safetensors:  30% 1.49G/4.90G [00:11<00:27, 125MB/s]
# model-00002-of-00003.safetensors:  31% 1.51G/4.90G [00:11<00:27, 126MB/s]
# model-00002-of-00003.safetensors:  31% 1.53G/4.90G [00:11<00:27, 124MB/s]
# model-00002-of-00003.safetensors:  32% 1.55G/4.90G [00:11<00:26, 127MB/s]
# model-00002-of-00003.safetensors:  32% 1.57G/4.90G [00:12<00:25, 129MB/s]
# model-00002-of-00003.safetensors:  32% 1.59G/4.90G [00:12<00:25, 129MB/s]
# model-00002-of-00003.safetensors:  33% 1.61G/4.90G [00:12<00:25, 130MB/s]
# model-00002-of-00003.safetensors:  33% 1.64G/4.90G [00:12<00:24, 132MB/s]
# model-00002-of-00003.safetensors:  34% 1.66G/4.90G [00:12<00:24, 133MB/s]
# model-00002-of-00003.safetensors:  34% 1.68G/4.90G [00:12<00:24, 134MB/s]
# model-00002-of-00003.safetensors:  35% 1.70G/4.90G [00:13<00:23, 135MB/s]
# model-00002-of-00003.safetensors:  35% 1.72G/4.90G [00:13<00:23, 135MB/s]
# model-00002-of-00003.safetensors:  35% 1.74G/4.90G [00:13<00:23, 136MB/s]
# model-00002-of-00003.safetensors:  36% 1.76G/4.90G [00:13<00:23, 137MB/s]
# model-00002-of-00003.safetensors:  36% 1.78G/4.90G [00:13<00:22, 137MB/s]
# model-00002-of-00003.safetensors:  37% 1.80G/4.90G [00:13<00:22, 137MB/s]
# model-00002-of-00003.safetensors:  37% 1.82G/4.90G [00:13<00:22, 136MB/s]
# model-00002-of-00003.safetensors:  38% 1.85G/4.90G [00:14<00:22, 136MB/s]
# model-00002-of-00003.safetensors:  38% 1.87G/4.90G [00:14<00:24, 126MB/s]
# model-00002-of-00003.safetensors:  38% 1.89G/4.90G [00:14<00:23, 130MB/s]
# model-00002-of-00003.safetensors:  39% 1.91G/4.90G [00:14<00:22, 132MB/s]
# model-00002-of-00003.safetensors:  39% 1.93G/4.90G [00:14<00:22, 133MB/s]
# model-00002-of-00003.safetensors:  40% 1.95G/4.90G [00:14<00:22, 134MB/s]
# model-00002-of-00003.safetensors:  40% 1.97G/4.90G [00:15<00:21, 135MB/s]
# model-00002-of-00003.safetensors:  41% 1.99G/4.90G [00:15<00:21, 136MB/s]
# model-00002-of-00003.safetensors:  41% 2.01G/4.90G [00:15<00:21, 136MB/s]
# model-00002-of-00003.safetensors:  41% 2.03G/4.90G [00:15<00:21, 137MB/s]
# model-00002-of-00003.safetensors:  42% 2.06G/4.90G [00:15<00:20, 136MB/s]
# model-00002-of-00003.safetensors:  42% 2.08G/4.90G [00:15<00:21, 134MB/s]
# model-00002-of-00003.safetensors:  43% 2.10G/4.90G [00:16<00:21, 130MB/s]
# model-00002-of-00003.safetensors:  43% 2.12G/4.90G [00:16<00:21, 129MB/s]
# model-00002-of-00003.safetensors:  44% 2.14G/4.90G [00:16<00:21, 128MB/s]
# model-00002-of-00003.safetensors:  44% 2.16G/4.90G [00:16<00:21, 127MB/s]
# model-00002-of-00003.safetensors:  44% 2.18G/4.90G [00:16<00:21, 127MB/s]
# model-00002-of-00003.safetensors:  45% 2.20G/4.90G [00:16<00:21, 126MB/s]
# model-00002-of-00003.safetensors:  45% 2.22G/4.90G [00:17<00:21, 127MB/s]
# model-00002-of-00003.safetensors:  46% 2.24G/4.90G [00:17<00:21, 125MB/s]
# model-00002-of-00003.safetensors:  46% 2.26G/4.90G [00:17<00:21, 125MB/s]
# model-00002-of-00003.safetensors:  47% 2.29G/4.90G [00:17<00:20, 126MB/s]
# model-00002-of-00003.safetensors:  61% 3.00G/4.90G [00:22<00:14, 128MB/s]
# model-00002-of-00003.safetensors:  62% 3.02G/4.90G [00:23<00:15, 126MB/s]
# model-00002-of-00003.safetensors:  62% 3.04G/4.90G [00:23<00:14, 125MB/s]
# model-00002-of-00003.safetensors:  62% 3.06G/4.90G [00:23<00:14, 124MB/s]
# model-00002-of-00003.safetensors:  63% 3.08G/4.90G [00:23<00:14, 123MB/s]
# model-00002-of-00003.safetensors:  63% 3.10G/4.90G [00:23<00:14, 123MB/s]
# model-00002-of-00003.safetensors:  64% 3.12G/4.90G [00:24<00:14, 124MB/s]
# model-00002-of-00003.safetensors:  64% 3.15G/4.90G [00:24<00:13, 127MB/s]
# model-00002-of-00003.safetensors:  65% 3.17G/4.90G [00:24<00:13, 128MB/s]
# model-00002-of-00003.safetensors:  65% 3.19G/4.90G [00:24<00:14, 122MB/s]
# model-00002-of-00003.safetensors:  65% 3.21G/4.90G [00:24<00:13, 124MB/s]
# model-00002-of-00003.safetensors:  66% 3.23G/4.90G [00:24<00:13, 125MB/s]
# model-00002-of-00003.safetensors:  66% 3.25G/4.90G [00:25<00:13, 125MB/s]
# model-00002-of-00003.safetensors:  67% 3.27G/4.90G [00:25<00:18, 90.3MB/s]
# model-00002-of-00003.safetensors:  67% 3.29G/4.90G [00:25<00:16, 100MB/s]
# model-00002-of-00003.safetensors:  68% 3.31G/4.90G [00:25<00:14, 110MB/s]
# model-00002-of-00003.safetensors:  68% 3.33G/4.90G [00:25<00:13, 116MB/s]
# model-00002-of-00003.safetensors:  68% 3.36G/4.90G [00:26<00:12, 120MB/s]
# model-00002-of-00003.safetensors:  69% 3.38G/4.90G [00:26<00:12, 124MB/s]
# model-00002-of-00003.safetensors:  69% 3.40G/4.90G [00:26<00:11, 126MB/s]
# model-00002-of-00003.safetensors:  70% 3.42G/4.90G [00:26<00:11, 129MB/s]
# model-00002-of-00003.safetensors:  70% 3.44G/4.90G [00:26<00:11, 129MB/s]
# model-00002-of-00003.safetensors:  71% 3.46G/4.90G [00:26<00:10, 131MB/s]
# model-00002-of-00003.safetensors:  71% 3.48G/4.90G [00:26<00:10, 133MB/s]
# model-00002-of-00003.safetensors:  71% 3.50G/4.90G [00:27<00:10, 130MB/s]
# model-00002-of-00003.safetensors:  72% 3.52G/4.90G [00:27<00:10, 131MB/s]
# model-00002-of-00003.safetensors:  72% 3.54G/4.90G [00:27<00:10, 133MB/s]
# model-00002-of-00003.safetensors:  73% 3.57G/4.90G [00:27<00:10, 133MB/s]
# model-00002-of-00003.safetensors:  73% 3.59G/4.90G [00:27<00:09, 132MB/s]
# model-00002-of-00003.safetensors:  74% 3.61G/4.90G [00:27<00:09, 132MB/s]
# model-00002-of-00003.safetensors:  74% 3.63G/4.90G [00:28<00:09, 131MB/s]
# model-00002-of-00003.safetensors:  74% 3.65G/4.90G [00:28<00:09, 131MB/s]
# model-00002-of-00003.safetensors:  75% 3.67G/4.90G [00:28<00:09, 129MB/s]
# model-00002-of-00003.safetensors:  75% 3.69G/4.90G [00:28<00:09, 130MB/s]
# model-00002-of-00003.safetensors:  76% 3.71G/4.90G [00:28<00:09, 129MB/s]
# model-00002-of-00003.safetensors:  76% 3.73G/4.90G [00:28<00:09, 130MB/s]
# model-00002-of-00003.safetensors:  77% 3.75G/4.90G [00:29<00:08, 130MB/s]
# model-00002-of-00003.safetensors:  77% 3.77G/4.90G [00:29<00:08, 131MB/s]
# model-00002-of-00003.safetensors:  77% 3.80G/4.90G [00:29<00:08, 131MB/s]
# model-00002-of-00003.safetensors:  78% 3.82G/4.90G [00:29<00:08, 133MB/s]
# model-00002-of-00003.safetensors:  78% 3.84G/4.90G [00:29<00:07, 134MB/s]
# model-00002-of-00003.safetensors:  79% 3.86G/4.90G [00:29<00:07, 136MB/s]
# model-00002-of-00003.safetensors:  79% 3.88G/4.90G [00:29<00:07, 134MB/s]
# model-00002-of-00003.safetensors:  80% 3.90G/4.90G [00:30<00:07, 132MB/s]
# model-00002-of-00003.safetensors:  80% 3.92G/4.90G [00:30<00:07, 131MB/s]
# model-00002-of-00003.safetensors:  80% 3.94G/4.90G [00:30<00:07, 129MB/s]
# model-00002-of-00003.safetensors:  81% 3.96G/4.90G [00:30<00:07, 127MB/s]
# model-00002-of-00003.safetensors:  81% 3.98G/4.90G [00:30<00:07, 130MB/s]
# model-00002-of-00003.safetensors:  82% 4.01G/4.90G [00:30<00:06, 130MB/s]
# model-00002-of-00003.safetensors:  82% 4.03G/4.90G [00:31<00:06, 132MB/s]
# model-00002-of-00003.safetensors:  83% 4.05G/4.90G [00:31<00:06, 134MB/s]
# model-00002-of-00003.safetensors:  83% 4.07G/4.90G [00:31<00:06, 135MB/s]
# model-00002-of-00003.safetensors:  83% 4.09G/4.90G [00:31<00:06, 134MB/s]
# model-00002-of-00003.safetensors:  84% 4.11G/4.90G [00:31<00:05, 134MB/s]
# model-00002-of-00003.safetensors:  84% 4.13G/4.90G [00:31<00:05, 135MB/s]
# model-00002-of-00003.safetensors:  85% 4.15G/4.90G [00:32<00:05, 135MB/s]
# model-00002-of-00003.safetensors:  85% 4.17G/4.90G [00:32<00:05, 134MB/s]
# model-00002-of-00003.safetensors:  86% 4.19G/4.90G [00:32<00:05, 130MB/s]
# model-00002-of-00003.safetensors:  86% 4.22G/4.90G [00:32<00:05, 130MB/s]
# model-00002-of-00003.safetensors:  86% 4.24G/4.90G [00:32<00:05, 132MB/s]
# model-00002-of-00003.safetensors:  87% 4.26G/4.90G [00:32<00:04, 134MB/s]
# model-00002-of-00003.safetensors:  87% 4.28G/4.90G [00:32<00:04, 135MB/s]
# model-00002-of-00003.safetensors:  88% 4.30G/4.90G [00:33<00:04, 134MB/s]
# model-00002-of-00003.safetensors:  88% 4.32G/4.90G [00:33<00:04, 133MB/s]
# model-00002-of-00003.safetensors:  89% 4.34G/4.90G [00:33<00:04, 135MB/s]
# model-00002-of-00003.safetensors:  89% 4.36G/4.90G [00:33<00:04, 135MB/s]
# model-00002-of-00003.safetensors:  89% 4.38G/4.90G [00:33<00:03, 136MB/s]
# model-00002-of-00003.safetensors:  90% 4.40G/4.90G [00:33<00:03, 134MB/s]
# model-00002-of-00003.safetensors:  90% 4.42G/4.90G [00:34<00:03, 134MB/s]
# model-00002-of-00003.safetensors:  91% 4.45G/4.90G [00:34<00:03, 135MB/s]
# model-00002-of-00003.safetensors:  91% 4.47G/4.90G [00:34<00:03, 136MB/s]
# model-00002-of-00003.safetensors:  92% 4.49G/4.90G [00:34<00:03, 136MB/s]
# model-00002-of-00003.safetensors:  92% 4.51G/4.90G [00:34<00:03, 119MB/s]
# model-00002-of-00003.safetensors:  92% 4.53G/4.90G [00:34<00:03, 122MB/s]
# model-00002-of-00003.safetensors:  93% 4.55G/4.90G [00:35<00:02, 127MB/s]
# model-00002-of-00003.safetensors:  93% 4.57G/4.90G [00:35<00:02, 128MB/s]
# model-00002-of-00003.safetensors:  94% 4.59G/4.90G [00:35<00:02, 131MB/s]
# model-00002-of-00003.safetensors:  94% 4.61G/4.90G [00:35<00:02, 130MB/s]
# model-00002-of-00003.safetensors:  94% 4.63G/4.90G [00:35<00:02, 131MB/s]
# model-00002-of-00003.safetensors:  95% 4.66G/4.90G [00:35<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  95% 4.68G/4.90G [00:36<00:01, 134MB/s]
# model-00002-of-00003.safetensors:  96% 4.70G/4.90G [00:36<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  96% 4.72G/4.90G [00:36<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  97% 4.74G/4.90G [00:36<00:01, 134MB/s]
# model-00002-of-00003.safetensors:  97% 4.76G/4.90G [00:36<00:01, 135MB/s]
# model-00002-of-00003.safetensors:  97% 4.78G/4.90G [00:36<00:00, 136MB/s]
# model-00002-of-00003.safetensors:  98% 4.80G/4.90G [00:36<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  98% 4.82G/4.90G [00:37<00:00, 131MB/s]
# model-00002-of-00003.safetensors:  99% 4.84G/4.90G [00:37<00:00, 134MB/s]
# model-00002-of-00003.safetensors:  99% 4.87G/4.90G [00:37<00:00, 131MB/s]
# model-00002-of-00003.safetensors: 100% 4.89G/4.90G [00:37<00:00, 132MB/s]
# model-00002-of-00003.safetensors: 100% 4.90G/4.90G [00:37<00:00, 130MB/s]
# Downloading shards:  67% 2/3 [01:17<00:38, 38.77s/it]
# model-00003-of-00003.safetensors:   0% 0.00/2.26G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   1% 21.0M/2.26G [00:00<00:16, 135MB/s]
# model-00003-of-00003.safetensors:   2% 41.9M/2.26G [00:00<00:16, 131MB/s]
# model-00003-of-00003.safetensors:   3% 62.9M/2.26G [00:00<00:16, 132MB/s]
# model-00003-of-00003.safetensors:   4% 83.9M/2.26G [00:00<00:16, 134MB/s]
# model-00003-of-00003.safetensors:   5% 105M/2.26G [00:00<00:15, 135MB/s]
# model-00003-of-00003.safetensors:   6% 126M/2.26G [00:00<00:15, 136MB/s]
# model-00003-of-00003.safetensors:  70% 1.57G/2.26G [00:12<00:05, 133MB/s]
# model-00003-of-00003.safetensors:  71% 1.59G/2.26G [00:12<00:05, 133MB/s]
# model-00003-of-00003.safetensors:  71% 1.61G/2.26G [00:12<00:04, 131MB/s]
# model-00003-of-00003.safetensors:  72% 1.64G/2.26G [00:12<00:04, 133MB/s]
# model-00003-of-00003.safetensors:  73% 1.66G/2.26G [00:12<00:04, 132MB/s]
# model-00003-of-00003.safetensors:  74% 1.68G/2.26G [00:13<00:04, 132MB/s]
# model-00003-of-00003.safetensors:  75% 1.70G/2.26G [00:13<00:04, 132MB/s]
# model-00003-of-00003.safetensors:  76% 1.72G/2.26G [00:13<00:04, 134MB/s]
# model-00003-of-00003.safetensors:  77% 1.74G/2.26G [00:13<00:03, 134MB/s]
# model-00003-of-00003.safetensors:  78% 1.76G/2.26G [00:13<00:03, 135MB/s]
# model-00003-of-00003.safetensors:  79% 1.78G/2.26G [00:13<00:03, 136MB/s]
# model-00003-of-00003.safetensors:  80% 1.80G/2.26G [00:14<00:03, 136MB/s]
# model-00003-of-00003.safetensors:  81% 1.82G/2.26G [00:14<00:03, 134MB/s]
# model-00003-of-00003.safetensors:  82% 1.85G/2.26G [00:14<00:03, 135MB/s]
# model-00003-of-00003.safetensors:  83% 1.87G/2.26G [00:14<00:02, 136MB/s]
# model-00003-of-00003.safetensors:  84% 1.89G/2.26G [00:14<00:02, 136MB/s]
# model-00003-of-00003.safetensors:  84% 1.91G/2.26G [00:14<00:02, 136MB/s]
# model-00003-of-00003.safetensors:  85% 1.93G/2.26G [00:14<00:02, 136MB/s]
# model-00003-of-00003.safetensors:  86% 1.95G/2.26G [00:15<00:02, 136MB/s]
# model-00003-of-00003.safetensors:  87% 1.97G/2.26G [00:15<00:02, 135MB/s]
# model-00003-of-00003.safetensors:  88% 1.99G/2.26G [00:15<00:02, 131MB/s]
# model-00003-of-00003.safetensors:  89% 2.01G/2.26G [00:15<00:01, 127MB/s]
# model-00003-of-00003.safetensors:  90% 2.03G/2.26G [00:15<00:01, 126MB/s]
# model-00003-of-00003.safetensors:  91% 2.06G/2.26G [00:15<00:01, 129MB/s]
# model-00003-of-00003.safetensors:  92% 2.08G/2.26G [00:16<00:01, 121MB/s]
# model-00003-of-00003.safetensors:  93% 2.10G/2.26G [00:16<00:01, 124MB/s]
# model-00003-of-00003.safetensors:  94% 2.12G/2.26G [00:16<00:01, 127MB/s]
# model-00003-of-00003.safetensors:  95% 2.14G/2.26G [00:16<00:00, 128MB/s]
# model-00003-of-00003.safetensors:  96% 2.16G/2.26G [00:16<00:00, 129MB/s]
# model-00003-of-00003.safetensors:  97% 2.18G/2.26G [00:16<00:00, 128MB/s]
# model-00003-of-00003.safetensors:  97% 2.20G/2.26G [00:17<00:00, 130MB/s]
# model-00003-of-00003.safetensors:  98% 2.22G/2.26G [00:17<00:00, 132MB/s]
# model-00003-of-00003.safetensors:  99% 2.24G/2.26G [00:17<00:00, 133MB/s]
# model-00003-of-00003.safetensors: 100% 2.26G/2.26G [00:17<00:00, 129MB/s]
# Downloading shards: 100% 3/3 [01:35<00:00, 31.86s/it]
# Loading checkpoint shards: 100% 3/3 [00:04<00:00,  1.56s/it]
# generation_config.json: 100% 111/111 [00:00<00:00, 568kB/s]
# 2024-04-27 13:26:03.804717: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:26:03.804782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:26:03.806262: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:26:05.045824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little girl who loved to play with her dolls. She had many dolls, and she played with them every day.
# One day the little girl's mother told her that she would be going to the store to buy some groceries. The little girl asked if she could go with her. Her mother said yes, and they went to the store.
# When they got to the store, the little girl saw a beautiful doll in the window. It was a very expensive doll, and it was made of wood. The little girl wanted to buy it, but her mother said that she couldn't afford it.
# The little girl was very sad, but she knew that her mother loved her very much. So she decided to wait until her mother came home from the store.
# When the little girl's mother came home, she told her that she had bought the doll for her. The little girl was very happy, and she thanked her mother for the doll.
# The little girl's mother told her that she would have to take care of the doll. She told the little girl that she would have to feed it, bathe it, and put it to bed.
# The little girl was very happy
#
#
# Generation took 160.85 seconds.

# %%
# !python generate_openelm.py --model apple/OpenELM-3B-Instruct \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 prompt_lookup_num_tokens=10
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# config.json: 100% 1.77k/1.77k [00:00<00:00, 8.36MB/s]
# configuration_openelm.py: 100% 14.3k/14.3k [00:00<00:00, 37.9MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-3B-Instruct:
# - configuration_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_openelm.py: 100% 39.3k/39.3k [00:00<00:00, 9.25MB/s]
# A new version of the following files was downloaded from https://huggingface.co/apple/OpenELM-3B-Instruct:
# - modeling_openelm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json: 100% 24.2k/24.2k [00:00<00:00, 51.0MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/4.94G [00:00<01:29, 55.2MB/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.94G [00:00<00:52, 93.3MB/s]
# model-00001-of-00002.safetensors:   1% 52.4M/4.94G [00:00<00:44, 111MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/4.94G [00:00<00:41, 118MB/s]
# model-00001-of-00002.safetensors:   2% 94.4M/4.94G [00:00<00:39, 123MB/s]
# model-00001-of-00002.safetensors:   2% 115M/4.94G [00:00<00:37, 128MB/s]
# model-00001-of-00002.safetensors:   3% 136M/4.94G [00:01<00:37, 128MB/s]
# model-00001-of-00002.safetensors:   3% 157M/4.94G [00:01<00:36, 130MB/s]
# model-00001-of-00002.safetensors:   4% 178M/4.94G [00:01<00:36, 130MB/s]
# model-00001-of-00002.safetensors:   4% 199M/4.94G [00:01<00:35, 133MB/s]
# model-00001-of-00002.safetensors:   4% 220M/4.94G [00:01<00:35, 134MB/s]
# model-00001-of-00002.safetensors:   5% 241M/4.94G [00:01<00:34, 135MB/s]
# model-00001-of-00002.safetensors:   5% 262M/4.94G [00:02<00:34, 136MB/s]
# model-00001-of-00002.safetensors:   6% 283M/4.94G [00:02<00:35, 132MB/s]
# model-00001-of-00002.safetensors:   6% 304M/4.94G [00:02<00:34, 133MB/s]
# model-00001-of-00002.safetensors:   7% 325M/4.94G [00:02<00:35, 130MB/s]
# model-00001-of-00002.safetensors:  77% 3.83G/4.94G [00:28<00:08, 139MB/s]
# model-00001-of-00002.safetensors:  78% 3.85G/4.94G [00:28<00:07, 139MB/s]
# model-00001-of-00002.safetensors:  78% 3.87G/4.94G [00:28<00:07, 139MB/s]
# model-00001-of-00002.safetensors:  79% 3.89G/4.94G [00:29<00:07, 139MB/s]
# model-00001-of-00002.safetensors:  79% 3.91G/4.94G [00:29<00:07, 138MB/s]
# model-00001-of-00002.safetensors:  80% 3.93G/4.94G [00:29<00:07, 135MB/s]
# model-00001-of-00002.safetensors:  80% 3.95G/4.94G [00:29<00:07, 129MB/s]
# model-00001-of-00002.safetensors:  80% 3.97G/4.94G [00:29<00:07, 129MB/s]
# model-00001-of-00002.safetensors:  81% 4.00G/4.94G [00:29<00:07, 131MB/s]
# model-00001-of-00002.safetensors:  81% 4.02G/4.94G [00:30<00:07, 131MB/s]
# model-00001-of-00002.safetensors:  82% 4.04G/4.94G [00:30<00:06, 131MB/s]
# model-00001-of-00002.safetensors:  82% 4.06G/4.94G [00:30<00:06, 129MB/s]
# model-00001-of-00002.safetensors:  83% 4.08G/4.94G [00:30<00:06, 131MB/s]
# model-00001-of-00002.safetensors:  83% 4.10G/4.94G [00:30<00:06, 134MB/s]
# model-00001-of-00002.safetensors:  83% 4.12G/4.94G [00:30<00:06, 135MB/s]
# model-00001-of-00002.safetensors:  84% 4.14G/4.94G [00:30<00:05, 137MB/s]
# model-00001-of-00002.safetensors:  84% 4.16G/4.94G [00:31<00:05, 138MB/s]
# model-00001-of-00002.safetensors:  85% 4.18G/4.94G [00:31<00:05, 138MB/s]
# model-00001-of-00002.safetensors:  85% 4.20G/4.94G [00:31<00:05, 139MB/s]
# model-00001-of-00002.safetensors:  85% 4.23G/4.94G [00:31<00:05, 139MB/s]
# model-00001-of-00002.safetensors:  86% 4.25G/4.94G [00:31<00:04, 140MB/s]
# model-00001-of-00002.safetensors:  86% 4.27G/4.94G [00:31<00:04, 140MB/s]
# model-00001-of-00002.safetensors:  87% 4.29G/4.94G [00:32<00:04, 140MB/s]
# model-00001-of-00002.safetensors:  87% 4.31G/4.94G [00:32<00:04, 140MB/s]
# model-00001-of-00002.safetensors:  88% 4.33G/4.94G [00:32<00:04, 138MB/s]
# model-00001-of-00002.safetensors:  88% 4.35G/4.94G [00:32<00:04, 138MB/s]
# model-00001-of-00002.safetensors:  88% 4.37G/4.94G [00:32<00:04, 139MB/s]
# model-00001-of-00002.safetensors:  89% 4.39G/4.94G [00:32<00:03, 139MB/s]
# model-00001-of-00002.safetensors:  89% 4.41G/4.94G [00:32<00:03, 139MB/s]
# model-00001-of-00002.safetensors:  90% 4.44G/4.94G [00:33<00:03, 140MB/s]
# model-00001-of-00002.safetensors:  90% 4.46G/4.94G [00:33<00:03, 140MB/s]
# model-00001-of-00002.safetensors:  91% 4.48G/4.94G [00:33<00:03, 140MB/s]
# model-00001-of-00002.safetensors:  91% 4.50G/4.94G [00:33<00:03, 140MB/s]
# model-00001-of-00002.safetensors:  91% 4.52G/4.94G [00:33<00:03, 140MB/s]
# model-00001-of-00002.safetensors:  92% 4.54G/4.94G [00:33<00:02, 140MB/s]
# model-00001-of-00002.safetensors:  92% 4.56G/4.94G [00:33<00:02, 140MB/s]
# model-00001-of-00002.safetensors:  93% 4.58G/4.94G [00:34<00:02, 140MB/s]
# model-00001-of-00002.safetensors:  93% 4.60G/4.94G [00:34<00:02, 135MB/s]
# model-00001-of-00002.safetensors:  94% 4.62G/4.94G [00:34<00:02, 134MB/s]
# model-00001-of-00002.safetensors:  94% 4.65G/4.94G [00:34<00:02, 134MB/s]
# model-00001-of-00002.safetensors:  94% 4.67G/4.94G [00:34<00:02, 135MB/s]
# model-00001-of-00002.safetensors:  95% 4.69G/4.94G [00:34<00:01, 134MB/s]
# model-00001-of-00002.safetensors:  95% 4.71G/4.94G [00:35<00:01, 132MB/s]
# model-00001-of-00002.safetensors:  96% 4.73G/4.94G [00:35<00:01, 133MB/s]
# model-00001-of-00002.safetensors:  96% 4.75G/4.94G [00:35<00:01, 133MB/s]
# model-00001-of-00002.safetensors:  97% 4.77G/4.94G [00:35<00:01, 131MB/s]
# model-00001-of-00002.safetensors:  97% 4.79G/4.94G [00:35<00:01, 132MB/s]
# model-00001-of-00002.safetensors:  97% 4.81G/4.94G [00:35<00:00, 134MB/s]
# model-00001-of-00002.safetensors:  98% 4.83G/4.94G [00:36<00:00, 136MB/s]
# model-00001-of-00002.safetensors:  98% 4.85G/4.94G [00:36<00:00, 137MB/s]
# model-00001-of-00002.safetensors:  99% 4.88G/4.94G [00:36<00:00, 138MB/s]
# model-00001-of-00002.safetensors:  99% 4.90G/4.94G [00:36<00:00, 138MB/s]
# model-00001-of-00002.safetensors:  99% 4.92G/4.94G [00:36<00:00, 138MB/s]
# model-00001-of-00002.safetensors: 100% 4.94G/4.94G [00:36<00:00, 134MB/s]
# Downloading shards:  50% 1/2 [00:37<00:37, 37.11s/it]
# model-00002-of-00002.safetensors:   0% 0.00/1.13G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   2% 21.0M/1.13G [00:00<00:08, 138MB/s]
# model-00002-of-00002.safetensors:   4% 41.9M/1.13G [00:00<00:08, 132MB/s]
# model-00002-of-00002.safetensors:   6% 62.9M/1.13G [00:00<00:07, 134MB/s]
# model-00002-of-00002.safetensors:   7% 83.9M/1.13G [00:00<00:07, 136MB/s]
# model-00002-of-00002.safetensors:   9% 105M/1.13G [00:00<00:07, 135MB/s]
# model-00002-of-00002.safetensors:  11% 126M/1.13G [00:00<00:07, 135MB/s]
# model-00002-of-00002.safetensors:  13% 147M/1.13G [00:01<00:07, 137MB/s]
# model-00002-of-00002.safetensors:  15% 168M/1.13G [00:01<00:07, 137MB/s]
# model-00002-of-00002.safetensors:  17% 189M/1.13G [00:01<00:06, 138MB/s]
# model-00002-of-00002.safetensors:  19% 210M/1.13G [00:01<00:06, 139MB/s]
# model-00002-of-00002.safetensors:  20% 231M/1.13G [00:01<00:06, 139MB/s]
# model-00002-of-00002.safetensors:  22% 252M/1.13G [00:01<00:06, 140MB/s]
# model-00002-of-00002.safetensors:  87% 986M/1.13G [00:07<00:01, 133MB/s]
# model-00002-of-00002.safetensors:  89% 1.01G/1.13G [00:07<00:00, 129MB/s]
# model-00002-of-00002.safetensors:  91% 1.03G/1.13G [00:07<00:00, 129MB/s]
# model-00002-of-00002.safetensors:  93% 1.05G/1.13G [00:07<00:00, 126MB/s]
# model-00002-of-00002.safetensors:  95% 1.07G/1.13G [00:07<00:00, 128MB/s]
# model-00002-of-00002.safetensors:  97% 1.09G/1.13G [00:08<00:00, 129MB/s]
# model-00002-of-00002.safetensors:  98% 1.11G/1.13G [00:08<00:00, 129MB/s]
# model-00002-of-00002.safetensors: 100% 1.13G/1.13G [00:08<00:00, 134MB/s]
# Downloading shards: 100% 2/2 [00:45<00:00, 22.84s/it]
# Loading checkpoint shards: 100% 2/2 [00:03<00:00,  1.78s/it]
# generation_config.json: 100% 111/111 [00:00<00:00, 445kB/s]
# 2024-04-27 13:29:06.069821: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:29:06.069891: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:29:06.071239: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:29:07.298585: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little girl named Rosie. Rosie loved to play dress-up, and her favorite costume was a princess dress. Her mother dressed Rosie in the princess dress every day, but Rosie wanted to wear it on special occasions, too.
#
# One day Rosie's mother told Rosie that Prince Charming would arrive at their house later that evening. Rosie couldn't wait! Prince Charming would surely ask Rosie to marry him, and she would wear her beautiful princess dress for their wedding. Rosie ran upstairs to get dressed.
#
# When Prince Charming arrived, Rosie wore her princess dress and tiara. Her mother helped her with her makeup, and Rosie practiced her curtsy. Prince Charming smiled and kissed Rosie's hand. Rosie hoped Prince Charming would ask her to marry him, but Prince Charming shook Rosie's hand instead. Prince Charming explained that Rosie's father had died when Rosie was very young, and Prince Charming wanted Rosie to choose her own husband. Rosie felt sad, but Prince Charming promised her
#
#
# Generation took 124.44 seconds.

# %% [markdown]
# ### use `assistant_model`
#
# - https://huggingface.co/blog/assisted-generation

# %%
# !python generate_openelm.py --model apple/OpenELM-3B \
  --hf_access_token $hf_token \
  --prompt 'Once upon a time there was' \
  --generate_kwargs repetition_penalty=1.2 \
  --assistant_model apple/OpenELM-270M
# Out:
# WARNING:root:No CUDA device detected, using cpu, expect slower speeds.
# Loading checkpoint shards: 100% 3/3 [00:08<00:00,  2.84s/it]
# 2024-04-27 13:32:23.732093: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 13:32:23.732169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 13:32:23.733612: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 13:32:25.183639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
#  Prompt + Generated Output
#
# Once upon a time there was a little girl who loved to play with her dolls. She had many dolls, and she played with them every day.
# One day the little girl's mother told her that she would be going to the store to buy some groceries. The little girl asked if she could go with her. Her mother said yes, and they went to the store.
# When they got to the store, the little girl saw a beautiful doll in the window. It was a very expensive doll, and it was made of wood. The little girl wanted to buy it, but her mother said that she couldn't afford it.
# The little girl was very sad, but she knew that her mother loved her very much. So she decided to wait until her mother came home from the store.
# When the little girl's mother came home, she told her that she had bought the doll for her. The little girl was very happy, and she thanked her mother for the doll.
# The little girl's mother told her that she would have to take care of the doll. She told the little girl that she would have to feed it, bathe it, and put it to bed.
# The little girl was
#
#
# Generation took 107.15 seconds.

# %% [markdown]
# # gradio

# %%
import torch
from threading import Thread
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch_dtype = torch.bfloat16 if torch.cuda.is_available() else torch.float32
low_cpu_mem_usage = True if torch.cuda.is_available() else False

checkpoint_tok = "meta-llama/Llama-2-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(checkpoint_tok)

checkpoint = "apple/OpenELM-270M"
model = AutoModelForCausalLM.from_pretrained(checkpoint, torch_dtype=torch_dtype, trust_remote_code=True, low_cpu_mem_usage=low_cpu_mem_usage)
model.to(device)

text_title = checkpoint.replace("/", " - ") + ' (' + str(model.device) + ') - Gradio Demo'

# %%
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
if tokenizer.pad_token == None:
  tokenizer.pad_token = tokenizer.eos_token
  tokenizer.pad_token_id = tokenizer.eos_token_id

# %%
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '</s>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
#from transformers import set_seed
#set_seed(42)
#Make sure we can generate text
text =  "Hello my name is Doron and I am"
inputs = tokenizer([text], return_tensors = "pt").input_ids.to(model.device)
pred_ids = model.generate(input_ids=inputs, do_sample=True, max_new_tokens=64, repetition_penalty=1.2)
#print(pred_ids)
pred_text = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
print(pred_text[0])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Hello my name is Doron and I am a 20-year-old student of Mechanical Engineering, pursuing the degree of Bachelor in Industrial Design.
# I have always been passionate about cars and the latest trends are just waiting for me to dive in! Having read many different books (both theoretical and practical) on the subject

# %%
# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 67.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.4/314.4 kB 30.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 7.7 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.

# %%
########################################################################
#                               Settings
########################################################################
import gradio as gr

#Set the maximum number of tokens to generate
max_new_tokens = 250

#Set a the value of the repetition penalty
#The higher the value, the less repetitive the generated text will be
#Note that `repetition_penalty` has to be a strictly positive float
repetition_penalty = 1.4

#Set the text direction
#For languages that are written from right to left (RTL), set rtl to True
rtl = False

########################################################################

print(f"Settings: max_new_tokens = {max_new_tokens}, repetition_penalty = {repetition_penalty}, rtl = {rtl}")

if rtl:
    text_title += " - RTL"
    text_align = 'right'
    css = "#output_text{direction: rtl} #input_text{direction: rtl}"
else:
    text_align = 'left'
    css = ""


def generate(text = ""):
    print("Create streamer")
    yield    "[Please wait for an answer]"

    decode_kwargs = dict(skip_special_tokens = True, clean_up_tokenization_spaces = True)
    streamer = TextIteratorStreamer(tokenizer, timeout = 5., decode_kwargs = decode_kwargs)

    inputs = tokenizer([text], return_tensors = "pt").input_ids.to(model.device)
    print(tokenizer.decode(inputs[0], skip_special_tokens=True))

    generation_kwargs = dict(input_ids=inputs, streamer = streamer, max_new_tokens=max_new_tokens, repetition_penalty=repetition_penalty)

    print("Create thread")
    thread = Thread(target = model.generate, kwargs = generation_kwargs)
    thread.start()
    generated_text = ""
    for new_text in streamer:
      if new_text == None:
          continue
      if tokenizer.eos_token not in new_text:
          new_text = new_text.replace(tokenizer.pad_token, "").replace(tokenizer.bos_token, "")
          yield generated_text + new_text
          print(new_text, end ="")
          generated_text += new_text
      else:
          new_text = new_text.replace(tokenizer.eos_token, "\n")
          print(new_text, end ="")
          generated_text += new_text
          return generated_text
    return generated_text
# Out:
# Settings: max_new_tokens = 250, repetition_penalty = 1.4, rtl = False

# %%
demo = gr.Interface(
        title = text_title,
        fn = generate,
        inputs = gr.Textbox(label = "Enter your prompt here", elem_id = "input_text", text_align = text_align, rtl = rtl),
        outputs = gr.Textbox(type = "text", label = "Generated text will appear here", elem_id = "output_text", text_align = text_align, rtl = rtl),
        css = css,
        allow_flagging = 'never'
)

demo.queue()
demo.launch(debug = True)
# Out:
# Settings: max_new_tokens = 250, repetition_penalty = 1.4, rtl = False
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://eedeb7dd82d4be9114.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://eedeb7dd82d4be9114.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Create streamer
# hi
# Create thread
#  hi, i'm a 20 year old female and have been on T for about 3 months now. I was diagnosed with PCOS in my early 20's but it wasn't until recently that i realized how much of a difference it made in my life.
#
# i started taking testosterone at the beginning of this month (1st week) because i wanted to see if i could get some more energy out of my body. i also noticed that my libido has increased significantly since starting T. i am not sure why or how it happened but i think it might be due to the fact that i feel like i can do anything i want when i take testosterone. i don't know what else to say other than that i love being able to go from day to day without having to worry about whether i will pass out or something.
#
# my biggest concern is that i still have trouble sleeping. i wake up feeling tired all the time and sometimes even after i've taken my pill i just lay there for hours. i've tried everything to help me fall asleep but nothing seems to work. i've had nightmares before but they are usuallyKeyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://eedeb7dd82d4be9114.gradio.live

# %%
checkpoint = "apple/OpenELM-3B"
model = AutoModelForCausalLM.from_pretrained(checkpoint, torch_dtype=torch_dtype, trust_remote_code=True, low_cpu_mem_usage=low_cpu_mem_usage)
model.to(device)

text_title = checkpoint.replace("/", " - ") + ' (' + str(model.device) + ') - Gradio Demo'
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
demo = gr.Interface(
        title = text_title,
        fn = generate,
        inputs = gr.Textbox(label = "Enter your prompt here", elem_id = "input_text", text_align = text_align, rtl = rtl),
        outputs = gr.Textbox(type = "text", label = "Generated text will appear here", elem_id = "output_text", text_align = text_align, rtl = rtl),
        css = css,
        allow_flagging = 'never'
)

demo.queue()
demo.launch(debug = True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://5e6144c78cf1dbed62.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5e6144c78cf1dbed62.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Create streamer
# hi
# Create thread
#  hi, i'm a 20 year old female and i have been having this problem for about 3 years now. it started when i was in the 7th grade (i'm currently in the 11th grade). my period is irregular but usually comes every 3 months or so. however, sometimes it will come every month or even twice in one month. i also get cramps that are very painful and last for days. they start off as mild cramps then become more intense until they are unbearable. i can't take any pain medication because i am allergic to most of them. i have tried taking tylenol with codeine which helps somewhat but not completely. i have also tried advil and motrin which do not help at all. i have seen several doctors over the years and they have never been able to find out what is wrong with me. some of the doctors have said that i may have endometriosis but i don't think that is the case because i haven't had surgery yet. i have also been tested for everything else under the sun including thyroid problems, diabetes, etc. nothing has
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Create streamer
# what you name?
# Create thread
#  what you name?
# I'm not sure if I should call it a "favorite" or a "least favorite." It's hard to say. But, for the sake of this post, I'll go with least favorite.
# The first time I saw The Notebook was in 2004 when I was still in high school. My mom and I went to see it
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Create streamer
# who are you?
# Create thread
#  who are you?
# I'm a 20-something year old girl from the UK. I love to read, write, and draw. I also like to play video games (mostly RPGs), watch anime, and listen to music. My favourite bands include The Beatles, Queen, Muse, Radiohead, Coldplay, and many more.
# what do you do?
# I work as a freelance writer for various websites and blogs. You can find my articles on this site or at other sites such as Blogcritics, PopMatters, and others.
# how did you get into writing?
# I started writing when I was about 13 years old. I wrote fanfiction in the Harry Potter fandom, which is where I got the idea to start writing original fiction. It wasn't until I was 16 that I actually began writing original fiction.
# where do you get your ideas?
# Most of my ideas come from dreams. Sometimes they just pop into my head while I'm awake, but most of the time they come from dreams. Other times, I'll be reading a book or watching a movie and think "I wishKeyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://5e6144c78cf1dbed62.gradio.live

# %% [markdown]
# # Evaluation

# %%
# %%bash
#
# # install public lm-eval-harness
#
# harness_repo="public-lm-eval-harness"
# git clone https://github.com/EleutherAI/lm-evaluation-harness ${harness_repo}
# cd ${harness_repo}
# # use main branch on 03-15-2024, SHA is dc90fec
# git checkout dc90fec
# pip install -e .
# cd ..

# %%
# 66d6242 is the main branch on 2024-04-01
# !pip install datasets@git+https://github.com/huggingface/datasets.git@66d6242
# Out:
# Collecting datasets@ git+https://github.com/huggingface/datasets.git@66d6242
#   Cloning https://github.com/huggingface/datasets.git (to revision 66d6242) to /tmp/pip-install-rl3x4fhl/datasets_9e3ce2aa5cb74fc68377b808acebfde5
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/datasets.git /tmp/pip-install-rl3x4fhl/datasets_9e3ce2aa5cb74fc68377b808acebfde5
#   WARNING: Did not find branch or tag '66d6242', assuming revision or ref.
#   Running command git checkout -q 66d6242
#   Resolved https://github.com/huggingface/datasets.git to commit 66d6242
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets@ git+https://github.com/huggingface/datasets.git@66d6242) (1.16.0)

# %%
# !pip install tokenizers>=0.15.2 transformers>=4.38.2 sentencepiece>=0.2.0

# %%
# OpenELM-270M-Instruct
hf_model="apple/OpenELM-270M-Instruct"

# this flag is needed because lm-eval-harness set add_bos_token to False by default, but OpenELM uses LLaMA tokenizer which requires add_bos_token to be True
tokenizer="meta-llama/Llama-2-7b-hf"
add_bos_token=True
batch_size=1

# %%
# !mkdir -p lm_eval_output

# %%
# zero-shot
# !lm_eval --model hf \
  --model_args pretrained=$hf_model,trust_remote_code=True,add_bos_token=$add_bos_token,tokenizer=$tokenizer \
  --tasks arc_challenge,arc_easy,boolq,hellaswag,piqa,race,winogrande,sciq,truthfulqa_mc2 \
  --device cuda:0 \
  --num_fewshot 0 \
  --output_path ./lm_eval_output/OpenELM-270M-Instruct-0shot \
  --batch_size $batch_size 2>&1 | tee ./lm_eval_output/eval-OpenELM-270M-Instruct-0shot.log
# Out:
# 2024-04-27 16:28:07.717163: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 16:28:07.717217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 16:28:07.718654: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-27 16:28:09.006591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-27:16:28:12,582 INFO     [__main__.py:225] Verbosity set to INFO
# 2024-04-27:16:28:12,582 INFO     [__init__.py:373] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-04-27:16:28:18,550 INFO     [__main__.py:311] Selected Tasks: ['arc_challenge', 'arc_easy', 'boolq', 'hellaswag', 'piqa', 'race', 'sciq', 'truthfulqa_mc2', 'winogrande']
# 2024-04-27:16:28:18,550 INFO     [__main__.py:312] Loading selected tasks...
# 2024-04-27:16:28:18,551 INFO     [evaluator.py:129] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-04-27:16:28:18,612 INFO     [huggingface.py:162] Using device 'cuda:0'
# 2024-04-27:16:28:23,704 INFO     [evaluator.py:190] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# Downloading readme: 100%|██████████| 9.00k/9.00k [00:00<00:00, 26.8MB/s]
# Downloading data: 100%|██████████| 190k/190k [00:01<00:00, 111kB/s]
# Downloading data: 100%|██████████| 204k/204k [00:01<00:00, 121kB/s]
# Downloading data: 100%|██████████| 55.7k/55.7k [00:01<00:00, 43.6kB/s]
# Generating train split: 100%|██████████| 1119/1119 [00:00<00:00, 37188.32 examples/s]
# Generating test split: 100%|██████████| 1172/1172 [00:00<00:00, 249706.61 examples/s]
# Generating validation split: 100%|██████████| 299/299 [00:00<00:00, 114247.69 examples/s]
# Downloading data: 100%|██████████| 331k/331k [00:01<00:00, 171kB/s]
# Downloading data: 100%|██████████| 346k/346k [00:01<00:00, 178kB/s]
# Downloading data: 100%|██████████| 86.1k/86.1k [00:01<00:00, 55.9kB/s]
# Generating train split: 100%|██████████| 2251/2251 [00:00<00:00, 321091.63 examples/s]
# Generating test split: 100%|██████████| 2376/2376 [00:00<00:00, 387076.30 examples/s]
# Generating validation split: 100%|██████████| 570/570 [00:00<00:00, 214609.81 examples/s]
# 2024-04-27:16:28:44,622 WARNING  [task.py:763] [Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# 2024-04-27:16:28:44,622 WARNING  [task.py:775] [Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading data: 100%|██████████| 3.85M/3.85M [00:00<00:00, 13.0MB/s]
# Downloading data: 100%|██████████| 1.31M/1.31M [00:00<00:00, 5.29MB/s]
# Downloading data: 100%|██████████| 1.31M/1.31M [00:00<00:00, 5.12MB/s]
# Generating train split: 100%|██████████| 9427/9427 [00:00<00:00, 265954.38 examples/s]
# Generating validation split: 100%|██████████| 3270/3270 [00:00<00:00, 310316.62 examples/s]
# Generating test split: 100%|██████████| 3245/3245 [00:00<00:00, 290760.87 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1483: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100%|██████████| 4.36k/4.36k [00:00<00:00, 18.1MB/s]
# Downloading metadata: 100%|██████████| 2.53k/2.53k [00:00<00:00, 13.4MB/s]
# Downloading readme: 100%|██████████| 6.84k/6.84k [00:00<00:00, 22.5MB/s]
# Downloading data: 47.5MB [00:00, 64.3MB/s]
# Downloading data: 11.8MB [00:00, 41.1MB/s]
# Downloading data: 12.2MB [00:00, 41.4MB/s]
# Generating train split: 100%|██████████| 39905/39905 [00:04<00:00, 8973.86 examples/s]
# Generating test split: 100%|██████████| 10003/10003 [00:01<00:00, 9216.75 examples/s]
# Generating validation split: 100%|██████████| 10042/10042 [00:01<00:00, 9179.34 examples/s]
# Map: 100%|██████████| 39905/39905 [00:06<00:00, 6049.60 examples/s]
# Map: 100%|██████████| 10042/10042 [00:01<00:00, 5544.56 examples/s]
# Downloading data: 100%|██████████| 2.66M/2.66M [00:02<00:00, 1.15MB/s]
# Downloading data: 100%|██████████| 502k/502k [00:00<00:00, 618kB/s]
# Downloading data: 100%|██████████| 301k/301k [00:00<00:00, 487kB/s]
# Generating train split: 100%|██████████| 16113/16113 [00:00<00:00, 607415.05 examples/s]
# Generating test split: 100%|██████████| 3084/3084 [00:00<00:00, 532445.61 examples/s]
# Generating validation split: 100%|██████████| 1838/1838 [00:00<00:00, 518156.39 examples/s]
# Downloading data: 100%|██████████| 1.64M/1.64M [00:02<00:00, 708kB/s]
# Generating test split: 100%|██████████| 1045/1045 [00:00<00:00, 71651.21 examples/s]
# 2024-04-27:16:29:47,765 WARNING  [task.py:322] [Task: race] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# 2024-04-27:16:29:47,765 WARNING  [task.py:322] [Task: race] has_training_docs and has_validation_docs are False, using test_docs as fewshot_docs but this is not recommended.
# Downloading readme: 100%|██████████| 7.02k/7.02k [00:00<00:00, 23.5MB/s]
# Downloading data: 100%|██████████| 3.99M/3.99M [00:07<00:00, 501kB/s]
# Downloading data: 100%|██████████| 339k/339k [00:02<00:00, 120kB/s]
# Downloading data: 100%|██████████| 343k/343k [00:03<00:00, 90.0kB/s]
# Generating train split: 100%|██████████| 11679/11679 [00:00<00:00, 308436.55 examples/s]
# Generating validation split: 100%|██████████| 1000/1000 [00:00<00:00, 194468.84 examples/s]
# Generating test split: 100%|██████████| 1000/1000 [00:00<00:00, 284109.19 examples/s]
# Downloading readme: 100%|██████████| 9.59k/9.59k [00:00<00:00, 29.2MB/s]
# Downloading data: 100%|██████████| 271k/271k [00:01<00:00, 155kB/s]
# Generating validation split: 100%|██████████| 817/817 [00:00<00:00, 166808.47 examples/s]
# Downloading data: 100%|██████████| 2.06M/2.06M [00:02<00:00, 889kB/s]
# Downloading data: 100%|██████████| 118k/118k [00:00<00:00, 180kB/s]
# Downloading data: 100%|██████████| 85.9k/85.9k [00:00<00:00, 205kB/s]
# Generating train split: 100%|██████████| 40398/40398 [00:00<00:00, 1064297.56 examples/s]
# Generating test split: 100%|██████████| 1767/1767 [00:00<00:00, 623063.07 examples/s]
# Generating validation split: 100%|██████████| 1267/1267 [00:00<00:00, 480486.72 examples/s]
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of winogrande from None to 0
# 2024-04-27:16:30:29,083 INFO     [evaluator.py:218] num_fewshot has been set to 0 for truthfulqa_mc2 in its config. Manual configuration will be ignored.
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of sciq from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of race from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of piqa from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of hellaswag from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of boolq from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_easy from None to 0
# 2024-04-27:16:30:29,083 WARNING  [evaluator.py:222] Overwriting default num_fewshot of arc_challenge from None to 0
# 2024-04-27:16:30:29,088 INFO     [task.py:395] Building contexts for winogrande on rank 0...
# 100%|██████████| 1267/1267 [00:00<00:00, 80714.82it/s]
# 2024-04-27:16:30:29,146 INFO     [task.py:395] Building contexts for truthfulqa_mc2 on rank 0...
# 100%|██████████| 817/817 [00:01<00:00, 675.13it/s]
# 2024-04-27:16:30:30,416 INFO     [task.py:395] Building contexts for sciq on rank 0...
# 100%|██████████| 1000/1000 [00:01<00:00, 696.64it/s]
# 2024-04-27:16:30:31,901 INFO     [task.py:395] Building contexts for race on rank 0...
# 100%|██████████| 1045/1045 [00:00<00:00, 3955.13it/s]
# 2024-04-27:16:30:32,192 INFO     [task.py:395] Building contexts for piqa on rank 0...
# 100%|██████████| 1838/1838 [00:01<00:00, 956.40it/s]
# 2024-04-27:16:30:34,183 INFO     [task.py:395] Building contexts for hellaswag on rank 0...
# 100%|██████████| 10042/10042 [00:04<00:00, 2345.05it/s]
# 2024-04-27:16:30:39,928 INFO     [task.py:395] Building contexts for boolq on rank 0...
# 100%|██████████| 3270/3270 [00:01<00:00, 1717.04it/s]
# 2024-04-27:16:30:41,953 INFO     [task.py:395] Building contexts for arc_easy on rank 0...
# 100%|██████████| 2376/2376 [00:02<00:00, 820.04it/s]
# 2024-04-27:16:30:44,988 INFO     [task.py:395] Building contexts for arc_challenge on rank 0...
# 100%|██████████| 1172/1172 [00:01<00:00, 997.32it/s]
# 2024-04-27:16:30:46,232 INFO     [evaluator.py:357] Running loglikelihood requests
# Running loglikelihood requests:   3%|▎         | 2371/81168 [06:00<2:44:34,  7.98it/s]

# %%
# five-shot
task="mmlu,winogrande"
# !lm_eval --model hf \
  --model_args pretrained=$hf_model,trust_remote_code=True,add_bos_token=$add_bos_token,tokenizer=$tokenizer \
  --tasks mmlu,winogrande \
  --device cuda:0 \
  --num_fewshot 5 \
  --output_path ./lm_eval_output/OpenELM-270M-Instruct-5shot \
  --batch_size $batch_size 2>&1 | tee ./lm_eval_output/eval-OpenELM-270M-Instruct-5shot.log

# %%
# 25-shot
task="arc_challenge,crows_pairs_english"
# !lm_eval --model hf \
  --model_args pretrained=$hf_model,trust_remote_code=True,add_bos_token=$add_bos_token,tokenizer=$tokenizer \
  --tasks arc_challenge,crows_pairs_english \
  --device cuda:0 \
  --num_fewshot 25 \
  --output_path ./lm_eval_output/OpenELM-270M-Instruct-25shot \
  --batch_size $batch_size 2>&1 | tee ./lm_eval_output/eval-OpenELM-270M-Instruct-25shot.log

# %%
# 10-shot
task="hellaswag"
# !lm_eval --model hf \
  --model_args pretrained=$hf_model,trust_remote_code=True,add_bos_token=$add_bos_token,tokenizer=$tokenizer \
  --tasks hellaswag \
  --device cuda:0 \
  --num_fewshot 10 \
  --output_path ./lm_eval_output/OpenELM-270M-Instruct-10shot \
  --batch_size $batch_size 2>&1 | tee ./lm_eval_output/eval-OpenELM-270M-Instruct-10shot.log
