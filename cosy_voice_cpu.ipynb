# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/cosy_voice_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          48 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   8
#   On-line CPU(s) list:    0-7
# Vendor ID:                AuthenticAMD
#   Model name:             AMD EPYC 7B12
#     CPU family:           23
#     Model:                49
#     Thread(s) per core:   2
#     Core(s) per socket:   4
#     Socket(s):            1
#     Stepping:             0
#     BogoMIPS:             4499.99
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 cl
#                           flush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm co
#                           nstant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni
#                           pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f
#                           16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse
#                           3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjus
#                           t bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsav
#                           ec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# Virtualization features:
#   Hypervisor vendor:      KVM
#   Virtualization type:    full
# Caches (sum of all):
#   L1d:                    128 KiB (4 instances)
#   L1i:                    128 KiB (4 instances)
#   L2:                     2 MiB (4 instances)
#   L3:                     16 MiB (1 instance)
# NUMA:
#   NUMA node(s):           1
#   NUMA node0 CPU(s):      0-7
# Vulnerabilities:
#   Gather data sampling:   Not affected
#   Itlb multihit:          Not affected
#   L1tf:                   Not affected
#   Mds:                    Not affected
#   Meltdown:               Not affected
#   Mmio stale data:        Not affected
#   Reg file data sampling: Not affected
#   Retbleed:               Vulnerable
#   Spec rstack overflow:   Vulnerable
#   Spec store bypass:      Vulnerable
#   Spectre v1:             Vulnerable: __user pointer sanitization and usercopy barriers only; no swa
#                           pgs barriers
#   Spectre v2:             Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-eIBRS: Not affected; BH
#                           I: Not affected
#   Srbds:                  Not affected
#   Tsx async abort:        Not affected

# %%
# !git clone --recursive https://github.com/FunAudioLLM/CosyVoice.git
# Out:
# Cloning into 'CosyVoice'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 316 (delta 58), reused 48 (delta 43), pack-reused 229
# Receiving objects: 100% (316/316), 767.13 KiB | 22.56 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'third_party/Matcha-TTS'
# Cloning into '/content/CosyVoice/third_party/Matcha-TTS'...
# remote: Enumerating objects: 916, done.
# remote: Counting objects: 100% (306/306), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 916 (delta 257), reused 214 (delta 213), pack-reused 610
# Receiving objects: 100% (916/916), 64.08 MiB | 57.71 MiB/s, done.
# Resolving deltas: 100% (416/416), done.
# Submodule path 'third_party/Matcha-TTS': checked out 'dd9105b34bf2be2230f4aa1e4769fb586a3c824e'

# %%
# !cd CosyVoice && pip install -r requirements.txt -i https://mirrors.aliyun.com/pypi/simple/ --trusted-host=mirrors.aliyun.com
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/, https://download.pytorch.org/whl/cu118
# Ignoring onnxruntime: markers 'sys_platform == "darwin" or sys_platform == "windows"' don't match your environment
# Collecting conformer==0.3.2 (from -r requirements.txt (line 2))
#   Downloading https://mirrors.aliyun.com/pypi/packages/3f/7d/714601ab8d790d77d4158af743895fb999216cb02fc6283ab8e54911a887/conformer-0.3.2-py3-none-any.whl (4.3 kB)
# Collecting deepspeed==0.14.2 (from -r requirements.txt (line 3))
#   Downloading https://mirrors.aliyun.com/pypi/packages/f0/84/a7b8ff287f7e1a5f01a010880b0bc5e58f718eaca784b4be592034eab3de/deepspeed-0.14.2.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting diffusers==0.27.2 (from -r requirements.txt (line 4))
#   Downloading https://mirrors.aliyun.com/pypi/packages/75/c5/3b84fd731dd93c549a0c25657e4ce5a957aeccd32d60dba2958cd3cdac23/diffusers-0.27.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: gdown==5.1.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (5.1.0)
# Collecting gradio==4.32.2 (from -r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/d1/37/f49320600cdf1fa856cc605a2e20e9debd34b5425b53f49abdb2ea463716/gradio-4.32.2-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 1.2 MB/s eta 0:00:00
# Collecting grpcio==1.57.0 (from -r requirements.txt (line 7))
#   Downloading https://mirrors.aliyun.com/pypi/packages/28/fa/c38a010d3fffcac07ef121abb34eb2c3db0876df74267ce5bde13c3a6ed7/grpcio-1.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.2 MB/s eta 0:00:00
# Collecting grpcio-tools==1.57.0 (from -r requirements.txt (line 8))
#   Downloading https://mirrors.aliyun.com/pypi/packages/00/8b/903898fcaf31f67180061983f6bf54027bc85ffb6f7b202f8263388fc2ae/grpcio_tools-1.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 1.2 MB/s eta 0:00:00
# Collecting hydra-core==1.3.2 (from -r requirements.txt (line 9))
#   Downloading https://mirrors.aliyun.com/pypi/packages/c6/50/e0edd38dcd63fb26a8547f13d28f7a008bc4a3fd4eb4ff030673f22ad41a/hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 1.2 MB/s eta 0:00:00
# Collecting HyperPyYAML==1.2.2 (from -r requirements.txt (line 10))
#   Downloading https://mirrors.aliyun.com/pypi/packages/33/c9/751b6401887f4b50f9307cc1e53d287b3dc77c375c126aeb6335aff73ccb/HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Collecting inflect==7.3.1 (from -r requirements.txt (line 11))
#   Downloading https://mirrors.aliyun.com/pypi/packages/c5/1c/b186bb7cf44e7fc19ac40a68b8cc971ec3d37ac246cf2582eb838304de8b/inflect-7.3.1-py3-none-any.whl (34 kB)
# Collecting librosa==0.10.2 (from -r requirements.txt (line 12))
#   Downloading https://mirrors.aliyun.com/pypi/packages/74/d4/cd10c82398f3b39bbf60a300e09c931bdf6844f3f2fba9ab2b5981501f9f/librosa-0.10.2-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 1.1 MB/s eta 0:00:00
# Collecting lightning==2.2.4 (from -r requirements.txt (line 13))
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/5e/d21fa170f971cba1700cb5bd695ea71da9dd4d1e85c7b080b68652ffdc5b/lightning-2.2.4-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 910.5 kB/s eta 0:00:00
# Collecting matplotlib==3.7.5 (from -r requirements.txt (line 14))
#   Downloading https://mirrors.aliyun.com/pypi/packages/b7/e2/f68aeaedf0ef57cbb793637ee82e62e64ea26cee908db0fe4f8e24d502c0/matplotlib-3.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 1.2 MB/s eta 0:00:00
# Collecting modelscope==1.15.0 (from -r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/80/3e/a59c0bcb192e4b26d253dd44b4385d65099e6d00cfcc15629efd03a43002/modelscope-1.15.0-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 1.2 MB/s eta 0:00:00
# Collecting networkx==3.1 (from -r requirements.txt (line 16))
#   Downloading https://mirrors.aliyun.com/pypi/packages/a8/05/9d4f9b78ead6b2661d6e8ea772e111fc4a9fbd866ad0c81906c11206b55e/networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.2 MB/s eta 0:00:00
# Collecting omegaconf==2.3.0 (from -r requirements.txt (line 17))
#   Downloading https://mirrors.aliyun.com/pypi/packages/e3/94/1843518e420fa3ed6919835845df698c7e27e183cb997394e4a670973a65/omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.1 MB/s eta 0:00:00
# Collecting onnxruntime-gpu==1.16.0 (from -r requirements.txt (line 18))
#   Downloading https://mirrors.aliyun.com/pypi/packages/8b/bb/550c2b3fa8c6a10af164354d74c07a5f3a3ef7c62ccdfe8d90576dea9edb/onnxruntime_gpu-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 MB 1.0 MB/s eta 0:00:00
# Collecting openai-whisper==20231117 (from -r requirements.txt (line 20))
#   Downloading https://mirrors.aliyun.com/pypi/packages/d2/6e/50ace2bf704e5ffc786d20d96403ab0d57c5d6ab8729de7fed8c436687df/openai-whisper-20231117.tar.gz (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting protobuf==4.25 (from -r requirements.txt (line 21))
#   Downloading https://mirrors.aliyun.com/pypi/packages/ae/32/45b1cf0c5d4a3ba881f5164c26af877c0dabfe6de0019d426aa0e5cf6806/protobuf-4.25.0-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.4/294.4 kB 1.0 MB/s eta 0:00:00
# Collecting pydantic==2.7.0 (from -r requirements.txt (line 22))
#   Downloading https://mirrors.aliyun.com/pypi/packages/16/ca/330c4f3bd983bb24ac12c7fd1e08c26c8aed70bc64498cf38c770321067f/pydantic-2.7.0-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.9/407.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: rich==13.7.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 23)) (13.7.1)
# Requirement already satisfied: soundfile==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 24)) (0.12.1)
# Collecting tensorboard==2.14.0 (from -r requirements.txt (line 25))
#   Downloading https://mirrors.aliyun.com/pypi/packages/bc/a2/ff5f4c299eb37c95299a76015da3f30211468e29d8d6f1d011683279baee/tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.0 MB/s eta 0:00:00
# Collecting torch==2.0.1 (from -r requirements.txt (line 26))
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 939.2 kB/s eta 0:00:00
# Collecting torchaudio==2.0.2 (from -r requirements.txt (line 27))
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 112.6 MB/s eta 0:00:00
# Collecting wget==3.2 (from -r requirements.txt (line 28))
#   Downloading https://mirrors.aliyun.com/pypi/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting WeTextProcessing==1.0.3 (from -r requirements.txt (line 29))
#   Downloading https://mirrors.aliyun.com/pypi/packages/ed/8f/c0fa549d04759fd48e27c55f8c2e69470c0228cbfba96ef3fef6a53bf383/WeTextProcessing-1.0.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Collecting einops>=0.6.1 (from conformer==0.3.2->-r requirements.txt (line 2))
#   Downloading https://mirrors.aliyun.com/pypi/packages/44/5a/f0b9ad6c0a9017e62d4735daaeb11ba3b6c009d69a26141b258cd37b5588/einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 959.4 kB/s eta 0:00:00
# Collecting hjson (from deepspeed==0.14.2->-r requirements.txt (line 3))
#   Downloading https://mirrors.aliyun.com/pypi/packages/1f/7f/13cd798d180af4bf4c0ceddeefba2b864a63c71645abc0308b768d67bb81/hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 1.0 MB/s eta 0:00:00
# Collecting ninja (from deepspeed==0.14.2->-r requirements.txt (line 3))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6d/92/8d7aebd4430ab5ff65df2bfee6d5745f95c004284db2d8ca76dcbfd9de47/ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.14.2->-r requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.14.2->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.14.2->-r requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.14.2->-r requirements.txt (line 3)) (9.0.0)
# Collecting pynvml (from deepspeed==0.14.2->-r requirements.txt (line 3))
#   Downloading https://mirrors.aliyun.com/pypi/packages/5b/9c/adb8070059caaa15d5a572b66bccd95900d8c1b9fa54d6ecea6ae97448d1/pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepspeed==0.14.2->-r requirements.txt (line 3)) (4.66.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (8.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (0.23.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.27.2->-r requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==5.1.0->-r requirements.txt (line 5)) (4.12.3)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (4.2.2)
# Collecting fastapi (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/e6/33/de41e554e5a187d583906e10d53bfae5fd6c07e98cbf4fe5262bd37e739a/fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.0 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/1d/70/07914754979f5dd80bda947a0ffd181c08bfcb137b01c3c0cef45254d271/ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.17.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/44/aa/aade28c6cd183a3b27fa2e21a8899e6ed705e27bc3b6055483677192eed8/gradio_client-0.17.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 1.1 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/41/7b/ddacf6dcebb42466abd03f368782142baa82e08fc0c1f8eaa05b4bae87d5/httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (2.1.5)
# Collecting orjson~=3.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/36/06/f5e0d6a921af2feae3c189514ebe12a6b8ab59ffe92c855996bcb4e6aa7f/orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (2.0.3)
# Collecting pydub (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/47/444768600d9e0ebc82f8e347775d24aef8f6348cf00e9fa0e81910814e6d/python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/8a/d5/8271d42dd239b7c2d163615b3b01b1acfb187f5114bfca6d5a85e1d6a1eb/ruff-0.5.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 1.1 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/68/4f/12207897848a653d03ebbf6775a29d949408ded5f99b2d87198bc5c93508/tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.2->-r requirements.txt (line 6)) (2.0.7)
# Collecting uvicorn>=0.14.0 (from gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/b2/f9/e6f30ba6094733e4f9794fd098ca0543a19b07ac1fa3075d595bf0f1fb60/uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools==1.57.0->-r requirements.txt (line 8)) (67.7.2)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core==1.3.2->-r requirements.txt (line 9))
#   Downloading https://mirrors.aliyun.com/pypi/packages/3e/38/7859ff46355f76f8d19459005ca000b6e7012f2f1ca597746cbcd1fbfe5e/antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml>=0.17.28 (from HyperPyYAML==1.2.2->-r requirements.txt (line 10))
#   Downloading https://mirrors.aliyun.com/pypi/packages/73/67/8ece580cc363331d9a53055130f86b096bf16e38156e33b1d3014fffda6b/ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 895.4 kB/s eta 0:00:00
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect==7.3.1->-r requirements.txt (line 11)) (10.1.0)
# Collecting typeguard>=4.0.1 (from inflect==7.3.1->-r requirements.txt (line 11))
#   Downloading https://mirrors.aliyun.com/pypi/packages/eb/de/be0ba39ee73760bf33329b7c6f95bc67e96593c69c881671e312538e24bb/typeguard-4.3.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (0.58.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.2->-r requirements.txt (line 12)) (1.0.8)
# Requirement already satisfied: fsspec[http]<2025.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from lightning==2.2.4->-r requirements.txt (line 13)) (2023.6.0)
# Collecting lightning-utilities<2.0,>=0.8.0 (from lightning==2.2.4->-r requirements.txt (line 13))
#   Downloading https://mirrors.aliyun.com/pypi/packages/75/6c/ccad49b96b38758ac77b04dc6d3795fb460fe0f8f311c75d0af0f8085cfb/lightning_utilities-0.11.3.post0-py3-none-any.whl (26 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning==2.2.4->-r requirements.txt (line 13))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6d/e6/e51997d1818a4c1a1ad2b1c7ca5ff9dd95969596add58b2ed39479026964/torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 1.1 MB/s eta 0:00:00
# Collecting pytorch-lightning (from lightning==2.2.4->-r requirements.txt (line 13))
#   Downloading https://mirrors.aliyun.com/pypi/packages/b9/4c/895eb1c4b20e34d86b76cc121ea85dd54ea3b42df9efdc21ec310810e986/pytorch_lightning-2.3.2-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.5->-r requirements.txt (line 14)) (2.8.2)
# Collecting addict (from modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/00/b08f23b7d7e1e14ce01419a467b583edbb93c6cdb8654e54a9cc579cd61f/addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from modelscope==1.15.0->-r requirements.txt (line 15)) (23.2.0)
# Collecting datasets<2.19.0,>=2.16.0 (from modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/95/fc/661a7f06e8b7d48fcbd3f55423b7ff1ac3ce59526f146fda87a1e1788ee4/datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: gast>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.15.0->-r requirements.txt (line 15)) (0.6.0)
# Collecting oss2 (from modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/bf/af/b2d6dee157e56cfd4489173d3a2aebdf57fc70a8e9901edc140e516065ac/oss2-2.18.6.tar.gz (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.8/283.8 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyarrow!=9.0.0,>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.15.0->-r requirements.txt (line 15)) (14.0.2)
# Collecting simplejson>=3.3.0 (from modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/cb/b6/ed513a0adc3e2c9654864ffb68266dcab5720d5653428d690e7e4fb32a6c/simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers>=1.5.9 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.15.0->-r requirements.txt (line 15)) (2.4.0)
# Collecting yapf (from modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/66/c9/d4b03b2490107f13ebd68fe9496d41ae41a7de6275ead56d0d4621b11ffd/yapf-0.40.2-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 1.1 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime-gpu==1.16.0->-r requirements.txt (line 18))
#   Downloading https://mirrors.aliyun.com/pypi/packages/a7/06/3d6badcf13db419e25b07041d9c7b4a2c331d3f4e7134445ec5df57714cd/coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 834.5 kB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.16.0->-r requirements.txt (line 18)) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu==1.16.0->-r requirements.txt (line 18)) (1.12.1)
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117->-r requirements.txt (line 20)) (2.3.0)
# Collecting tiktoken (from openai-whisper==20231117->-r requirements.txt (line 20))
#   Downloading https://mirrors.aliyun.com/pypi/packages/e7/8c/7d1007557b343d5cf18349802e94d3a14397121e9105b4661f8cd753f9bf/tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.7.0->-r requirements.txt (line 22)) (0.7.0)
# Collecting pydantic-core==2.18.1 (from pydantic==2.7.0->-r requirements.txt (line 22))
#   Downloading https://mirrors.aliyun.com/pypi/packages/57/10/e5b53ab5e11719d899e9cc5cccab1147e0c9f8a2643099b0184e50df0ad8/pydantic_core-2.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->-r requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich==13.7.1->-r requirements.txt (line 23)) (2.16.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile==0.12.1->-r requirements.txt (line 24)) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard==2.14.0->-r requirements.txt (line 25))
#   Downloading https://mirrors.aliyun.com/pypi/packages/4a/07/8d9a8186e6768b55dfffeb57c719bc03770cf8a970a074616ae6f9e26a57/google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.14.0->-r requirements.txt (line 25)) (0.43.0)
# Collecting triton<3,>=2.0.0 (from openai-whisper==20231117->-r requirements.txt (line 20))
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 20.9 MB/s eta 0:00:00
# Collecting pynini==2.1.5 (from WeTextProcessing==1.0.3->-r requirements.txt (line 29))
#   Downloading https://mirrors.aliyun.com/pypi/packages/e7/07/f3b8869878093fe7d119cbdcc97de0b64e4b8e2a7933c817fcef1fe455bb/pynini-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 MB 1.1 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.17.0->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/58/0a/7570e15661a0a546c3a1152d95fe8c05480459bab36247f0acbf41f01a41/websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.10/dist-packages (from pynini==2.1.5->WeTextProcessing==1.0.3->-r requirements.txt (line 29)) (3.0.10)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117->-r requirements.txt (line 20)) (3.27.9)
# Collecting lit (from triton<3,>=2.0.0->openai-whisper==20231117->-r requirements.txt (line 20))
#   Downloading https://mirrors.aliyun.com/pypi/packages/96/06/b36f150fa7c5bcc96a31a4d19a20fddbd1d965b6f02510b57a3bb8d4b930/lit-18.1.8-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile==0.12.1->-r requirements.txt (line 24)) (2.22)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/c9/7a/cef76fd8438a42f96db64ddaa85280485a9c395e7df3db8158cfec1eee34/dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 1.3 MB/s eta 0:00:00
# Collecting xxhash (from datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/80/8a/1dd41557883b6196f8f092011a5c1f72d4d44cf36d7b67d4a5efe3127949/xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 1.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/bc/f7/7ec7fddc92e50714ea3745631f79bd9c96424cb2702632521028e57d3a36/multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (3.9.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 25)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 25)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 25)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard==2.14.0->-r requirements.txt (line 25)) (1.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6)) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/78/d4/e5d7e4f2174f8a4d63c8897d79eb8fe2503f7ecc03282fee1fa2719c2704/httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6)) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6)) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich==13.7.1->-r requirements.txt (line 23)) (0.1.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa==0.10.2->-r requirements.txt (line 12)) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.32.2->-r requirements.txt (line 6)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.32.2->-r requirements.txt (line 6)) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa==0.10.2->-r requirements.txt (line 12)) (4.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.5->-r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.27.2->-r requirements.txt (line 4)) (3.3.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->HyperPyYAML==1.2.2->-r requirements.txt (line 10))
#   Downloading https://mirrors.aliyun.com/pypi/packages/d3/62/c60b034d9a008bbd566eeecf53a5a4c73d191c8de261290db6761802b72d/ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.2->-r requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.32.2->-r requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.32.2->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==5.1.0->-r requirements.txt (line 5)) (2.5)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.16.0->-r requirements.txt (line 18))
#   Downloading https://mirrors.aliyun.com/pypi/packages/f0/0f/310fb31e39e2d734ccaa2c0fb981ee41f7bd5056ce9bc29b2248bd569169/humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.1 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/fd/18/31fa32ed6c68ba66220204ef0be798c349d0a20c1901f9d4a794e08c76d8/starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 1.1 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/a1/03/89bf615052aa5453c04d952225ded0b88aab6487b9c5f0c268939d13b860/fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/b4/6d/0df8f7a6f1944ba619d93025ce468c9252aa10799d7140e07014dfc1a16c/ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 1.1 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/d7/ee/bf0adb559ad3c786f12bcbc9296b3f5675f529199bef03e2df281fa1fadb/email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.27.2->-r requirements.txt (line 4)) (3.19.2)
# Collecting crcmod>=1.7 (from oss2->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6b/b0/e595ce2a2527e169c3bcd6c33d2473c1918e0b7f6826a043ca1245dd4e5b/crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/af/20/5f29ec45462360e7f61e8688af9fe4a0afae057edfabdada662e11bf97e7/pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.3 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/89/b4/ad457761ca26b18a9b0f534b84fec2df59c5fde62dc7786768e2b0edd702/aliyun_python_sdk_kms-2.16.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 1.3 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/3a/e6/f579e8a5e26ef1066f6fb11074cedc9f668cb5f722c85cf7adc0f7e2e23e/aliyun-python-sdk-core-2.15.1.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.27.2->-r requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime-gpu==1.16.0->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope==1.15.0->-r requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<2.19.0,>=2.16.0->modelscope==1.15.0->-r requirements.txt (line 15)) (4.0.3)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.15.0->-r requirements.txt (line 15))
#   Downloading https://mirrors.aliyun.com/pypi/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.15.0->-r requirements.txt (line 15)) (42.0.8)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.2->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 25)) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard==2.14.0->-r requirements.txt (line 25)) (3.2.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio==4.32.2->-r requirements.txt (line 6)) (1.2.1)
# Collecting httptools>=0.5.0 (from uvicorn>=0.14.0->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/65/e7/dd5ba95c84047118a363f0755ad78e639e0529be92424bb020496578aa3b/httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 1.1 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn>=0.14.0->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn>=0.14.0->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/ab/ed/12729fba5e3b7e02ee70b3ea230b88e60a50375cf63300db22607694d2f0/uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.2 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn>=0.14.0->gradio==4.32.2->-r requirements.txt (line 6))
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/ae/e7eddbdca559f14a9a38cf04782a5d715cf350aad498d0862fb02b4ebe10/watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.2 MB/s eta 0:00:00
# Building wheels for collected packages: deepspeed, openai-whisper, wget, antlr4-python3-runtime, ffmpy, oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.14.2-py3-none-any.whl size=1432123 sha256=2f3caddbd55dc4995eba34a3f5626ff24973a828c704df84e5dc2c858439ae4e
#   Stored in directory: /root/.cache/pip/wheels/19/41/77/076aea6f5cc452dd7bf8e68ba3cdc0e2d6fa1b966cf2a6355b
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801359 sha256=63688ff1c08163a7b9c9b020ddc44e48c6324fa27242216adab7e832dbdf420d
#   Stored in directory: /root/.cache/pip/wheels/0c/d5/c9/b01e0ad02f7fbca56976f6c25ebbe4e5ee7042e91ebf3d5c7e
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=1778518e4d4e2cee1191f9fecd1f0a0faf5e4d57dc900d3b6531a33ad73fa21d
#   Stored in directory: /root/.cache/pip/wheels/01/20/16/441e0a41251b6ff4e489ba01a3ce4a62f6476b5affa0bbb4a4
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=5669189bc00a55a62bb2e6c9f94cf43802da9673e0c456c138c9a9921c5bef45
#   Stored in directory: /root/.cache/pip/wheels/79/82/b1/b79d6e90f34257cd436860ed4f4a09f9e1ea8cd32da7046ea4
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=e1be2e929d23b14d76d6b37cf7c88cb1270a66b05827e8eb86ad56869afa2680
#   Stored in directory: /root/.cache/pip/wheels/d5/ba/8f/dde85c39f765c48a489063a576d1ec23a0097b155e2fc243f0
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.18.6-py3-none-any.whl size=118355 sha256=f763f39829d02794eb52cac1210ec1e5d91f50a5b69801d8a9a0315102f63d26
#   Stored in directory: /root/.cache/pip/wheels/80/eb/ca/90b3a95488e264b48e012c2e4afc41c94757031ac382f18a84
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.1-py3-none-any.whl size=535325 sha256=c49fdddd52e7f1b83444588e9e3d681346a98b4d9dce653dcbdd860c11c787ee
#   Stored in directory: /root/.cache/pip/wheels/2f/bd/89/02cd85ecd77defbce5a0585de6b9a82f111d6e1ec1945fccd9
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31403 sha256=d88a879a0bbfaa27546d8e90a38cd5d507d2fdc891e9338401ff8a4e2ebf2689
#   Stored in directory: /root/.cache/pip/wheels/aa/64/0d/d371a836ec27ec35ef16ce7b8dae4898f6e1ffb309268bfceb
# Successfully built deepspeed openai-whisper wget antlr4-python3-runtime ffmpy oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: wget, pydub, ninja, lit, hjson, ffmpy, crcmod, antlr4-python3-runtime, addict, xxhash, websockets, uvloop, ujson, typeguard, tomlkit, simplejson, semantic-version, ruff, ruamel.yaml.clib, python-multipart, python-dotenv, pynvml, pynini, pydantic-core, pycryptodome, protobuf, orjson, omegaconf, networkx, lightning-utilities, jmespath, humanfriendly, httptools, h11, grpcio, einops, dnspython, dill, aiofiles, yapf, WeTextProcessing, watchfiles, uvicorn, tiktoken, starlette, ruamel.yaml, pydantic, multiprocess, matplotlib, inflect, hydra-core, httpcore, grpcio-tools, email_validator, coloredlogs, onnxruntime-gpu, librosa, HyperPyYAML, httpx, google-auth-oauthlib, diffusers, aliyun-python-sdk-core, tensorboard, gradio-client, fastapi-cli, datasets, aliyun-python-sdk-kms, oss2, fastapi, modelscope, gradio, triton, torch, torchmetrics, pytorch-lightning, torchaudio, openai-whisper, lightning, deepspeed, conformer
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.0
#     Uninstalling pydantic_core-2.20.0:
#       Successfully uninstalled pydantic_core-2.20.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.0
#     Uninstalling pydantic-2.8.0:
#       Successfully uninstalled pydantic-2.8.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: inflect
#     Found existing installation: inflect 7.0.0
#     Uninstalling inflect-7.0.0:
#       Successfully uninstalled inflect-7.0.0
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.3.0+cu121
#     Uninstalling torchaudio-2.3.0+cu121:
#       Successfully uninstalled torchaudio-2.3.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0 requires tensorboard<2.16,>=2.15, but you have tensorboard 2.14.0 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.0.1+cu118 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed HyperPyYAML-1.2.2 WeTextProcessing-1.0.3 addict-2.4.0 aiofiles-23.2.1 aliyun-python-sdk-core-2.15.1 aliyun-python-sdk-kms-2.16.3 antlr4-python3-runtime-4.9.3 coloredlogs-15.0.1 conformer-0.3.2 crcmod-1.7 datasets-2.18.0 deepspeed-0.14.2 diffusers-0.27.2 dill-0.3.8 dnspython-2.6.1 einops-0.8.0 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 ffmpy-0.3.2 google-auth-oauthlib-1.0.0 gradio-4.32.2 gradio-client-0.17.0 grpcio-1.57.0 grpcio-tools-1.57.0 h11-0.14.0 hjson-3.1.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 hydra-core-1.3.2 inflect-7.3.1 jmespath-0.10.0 librosa-0.10.2 lightning-2.2.4 lightning-utilities-0.11.3.post0 lit-18.1.8 matplotlib-3.7.5 modelscope-1.15.0 multiprocess-0.70.16 networkx-3.1 ninja-1.11.1.1 omegaconf-2.3.0 onnxruntime-gpu-1.16.0 openai-whisper-20231117 orjson-3.10.6 oss2-2.18.6 protobuf-4.25.0 pycryptodome-3.20.0 pydantic-2.7.0 pydantic-core-2.18.1 pydub-0.25.1 pynini-2.1.5 pynvml-11.5.0 python-dotenv-1.0.1 python-multipart-0.0.9 pytorch-lightning-2.3.2 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 ruff-0.5.1 semantic-version-2.10.0 simplejson-3.19.2 starlette-0.37.2 tensorboard-2.14.0 tiktoken-0.7.0 tomlkit-0.12.0 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchmetrics-1.4.0.post0 triton-2.0.0 typeguard-4.3.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-11.0.3 wget-3.2 xxhash-3.4.1 yapf-0.40.2

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# %cd /content/CosyVoice
# git模型下载，请确保已安装git lfs
#!rm -rf pretrained_models
# !mkdir -p pretrained_models
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M.git pretrained_models/CosyVoice-300M
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M-SFT.git pretrained_models/CosyVoice-300M-SFT
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M-Instruct.git pretrained_models/CosyVoice-300M-Instruct
# !git clone https://www.modelscope.cn/iic/CosyVoice-ttsfrd.git pretrained_models/CosyVoice-ttsfrd
# Out:
# /content/CosyVoice
# Cloning into 'pretrained_models/CosyVoice-300M'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 3), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (20/20), 7.66 KiB | 7.66 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Filtering content: 100% (6/6), 2.13 GiB | 28.07 MiB/s, done.
# Cloning into 'pretrained_models/CosyVoice-300M-SFT'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (20/20), 7.72 KiB | 7.72 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Filtering content: 100% (6/6), 2.13 GiB | 16.03 MiB/s, done.
# Cloning into 'pretrained_models/CosyVoice-300M-Instruct'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (20/20), 7.71 KiB | 7.71 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Filtering content: 100% (6/6), 2.13 GiB | 24.17 MiB/s, done.
# Cloning into 'pretrained_models/CosyVoice-ttsfrd'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (15/15), 3.59 MiB | 7.84 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !cd pretrained_models/CosyVoice-ttsfrd/ && wget https://www.modelscope.cn/models/speech_tts/speech_kantts_ttsfrd/resolve/master/ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl
# Out:
# --2024-07-10 10:51:03--  https://www.modelscope.cn/models/speech_tts/speech_kantts_ttsfrd/resolve/master/ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl
# Resolving www.modelscope.cn (www.modelscope.cn)... 47.251.62.57
# Connecting to www.modelscope.cn (www.modelscope.cn)|47.251.62.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4005795 (3.8M) [application/octet-stream]
# Saving to: ‘ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl’
#
# ttsfrd-0.3.9-cp310- 100%[===================>]   3.82M  2.85MB/s    in 1.3s
#
# 2024-07-10 10:51:06 (2.85 MB/s) - ‘ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl’ saved [4005795/4005795]

# %%
# !ls pretrained_models/CosyVoice-ttsfrd/
# Out:
# configuration.json  resource	  ttsfrd-0.3.6-cp38-cp38-linux_x86_64.whl
# README.md	    resource.zip  ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl

# %%
#!cd pretrained_models/CosyVoice-ttsfrd/ && unzip resource.zip -d .
# !pip install pretrained_models/CosyVoice-ttsfrd/ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl
# Out:
# Processing ./pretrained_models/CosyVoice-ttsfrd/ttsfrd-0.3.9-cp310-cp310-linux_x86_64.whl
# Installing collected packages: ttsfrd
# Successfully installed ttsfrd-0.3.9

# %%
# !ls /content/CosyVoice/third_party/Matcha-TTS
# Out:
# configs  LICENSE   MANIFEST.in	notebooks	README.md	  scripts   synthesis.ipynb
# data	 Makefile  matcha	pyproject.toml	requirements.txt  setup.py

# %%
! echo $PYTHONPATH

import os
os.environ['PYTHONPATH'] += ":/content/CosyVoice/third_party/Matcha-TTS"

! echo $PYTHONPATH
# Out:
# /env/python
# /env/python:/content/CosyVoice/third_party/Matcha-TTS

# %%
# %cd /content/CosyVoice
# Out:
# /content/CosyVoice

# %%
! echo $PYTHONPATH
# Out:
# /env/python:/content/CosyVoice/third_party/Matcha-TTS

# %%
import sys
print(sys.path)
sys.path.insert(1, "/content/CosyVoice/third_party/Matcha-TTS")
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']

# %%
print(sys.path)
# Out:
# ['/content', '/content/CosyVoice/third_party/Matcha-TTS', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']

# %%
from cosyvoice.cli.cosyvoice import CosyVoice
from cosyvoice.utils.file_utils import load_wav
import torchaudio
import time

cosyvoice = CosyVoice('pretrained_models/CosyVoice-300M-SFT')
# sft usage
print(cosyvoice.list_avaliable_spks())
s = time.time()
output = cosyvoice.inference_sft('你好，我是通义生成式语音大模型，请问有什么可以帮您的吗？', '中文女')
print("sft",time.time()-s)
torchaudio.save('sft.wav', output['tts_speech'], 22050)

cosyvoice = CosyVoice('pretrained_models/CosyVoice-300M')
# zero_shot usage, <|zh|><|en|><|jp|><|yue|><|ko|> for Chinese/English/Japanese/Cantonese/Korean
prompt_speech_16k = load_wav('zero_shot_prompt.wav', 16000)
s = time.time()
output = cosyvoice.inference_zero_shot('收到好友从远方寄来的生日礼物，那份意外的惊喜与深深的祝福让我心中充满了甜蜜的快乐，笑容如花儿般绽放。', '希望你以后能够做的比我还好呦。', prompt_speech_16k)
print("zero_shot",time.time()-s)
torchaudio.save('zero_shot.wav', output['tts_speech'], 22050)
# cross_lingual usage
prompt_speech_16k = load_wav('cross_lingual_prompt.wav', 16000)
s = time.time()
output = cosyvoice.inference_cross_lingual('<|en|>And then later on, fully acquiring that company. So keeping management in line, interest in line with the asset that\'s coming into the family is a reason why sometimes we don\'t buy the whole thing.', prompt_speech_16k)
print("cross_lingual",time.time()-s)
torchaudio.save('cross_lingual.wav', output['tts_speech'], 22050)

cosyvoice = CosyVoice('pretrained_models/CosyVoice-300M-Instruct')
# instruct usage, support <laughter></laughter><strong></strong>[laughter][breath]
s = time.time()
output = cosyvoice.inference_instruct('在面对挑战时，他展现了非凡的<strong>勇气</strong>与<strong>智慧</strong>。', '中文男', 'Theo \'Crimson\', is a fiery, passionate rebel leader. Fights with fervor for justice, but struggles with impulsiveness.')
print("instruct",time.time()-s)
torchaudio.save('instruct.wav', output['tts_speech'], 22050)
# Out:
# /usr/local/lib/python3.10/dist-packages/diffusers/models/lora.py:393: FutureWarning: `LoRACompatibleLinear` is deprecated and will be removed in version 1.0.0. Use of `LoRACompatibleLinear` is deprecated. Please switch to PEFT backend by installing PEFT: `pip install peft`.
#   deprecate("LoRACompatibleLinear", "1.0.0", deprecation_message)
# 2024-07-10 11:26:36,026 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:26:36,026 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:26:36,026 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:26:36,026 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# INFO:wetext-zh_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:26:36,032 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:26:36,032 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:26:36,032 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:26:36,032 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# INFO:wetext-zh_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:26:36,040 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:26:36,040 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:26:36,040 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:26:36,040 WETEXT INFO skip building fst for zh_normalizer ...
# INFO:wetext-zh_normalizer:skip building fst for zh_normalizer ...
# 2024-07-10 11:26:37,434 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:26:37,434 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:26:37,434 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:26:37,434 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# INFO:wetext-en_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:26:37,439 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:26:37,439 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:26:37,439 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:26:37,439 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# INFO:wetext-en_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:26:37,443 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:26:37,443 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:26:37,443 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:26:37,443 WETEXT INFO skip building fst for en_normalizer ...
# INFO:wetext-en_normalizer:skip building fst for en_normalizer ...
# ['中文女', '中文男', '日语男', '粤语女', '英文女', '英文男', '韩语女']
# sft 32.36278009414673
# 2024-07-10 11:27:22,886 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:27:22,886 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:27:22,886 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:27:22,886 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:27:22,886 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# INFO:wetext-zh_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:27:22,894 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:27:22,894 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:27:22,894 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:27:22,894 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:27:22,894 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# INFO:wetext-zh_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:27:22,901 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:27:22,901 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:27:22,901 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:27:22,901 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:27:22,901 WETEXT INFO skip building fst for zh_normalizer ...
# INFO:wetext-zh_normalizer:skip building fst for zh_normalizer ...
# 2024-07-10 11:27:24,482 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:27:24,482 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:27:24,482 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:27:24,482 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:27:24,482 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# INFO:wetext-en_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:27:24,494 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:27:24,494 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:27:24,494 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:27:24,494 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:27:24,494 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# INFO:wetext-en_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:27:24,504 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:27:24,504 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:27:24,504 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:27:24,504 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:27:24,504 WETEXT INFO skip building fst for en_normalizer ...
# INFO:wetext-en_normalizer:skip building fst for en_normalizer ...
# zero_shot 150.94990277290344
# min value is  tensor(-1.0054)
# cross_lingual 165.97446990013123
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,240 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# INFO:wetext-zh_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/zh_tn_tagger.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,252 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# INFO:wetext-zh_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/zh_tn_verbalizer.fst
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# 2024-07-10 11:32:53,260 WETEXT INFO skip building fst for zh_normalizer ...
# INFO:wetext-zh_normalizer:skip building fst for zh_normalizer ...
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,893 WETEXT INFO found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# INFO:wetext-en_normalizer:found existing fst: /usr/local/lib/python3.10/dist-packages/tn/en_tn_tagger.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,905 WETEXT INFO                     /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# INFO:wetext-en_normalizer:                    /usr/local/lib/python3.10/dist-packages/tn/en_tn_verbalizer.fst
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# 2024-07-10 11:32:54,913 WETEXT INFO skip building fst for en_normalizer ...
# INFO:wetext-en_normalizer:skip building fst for en_normalizer ...
# instruct 42.04965257644653

# %%
from IPython.display import Audio
Audio("sft.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("zero_shot.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("cross_lingual.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("instruct.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 总结
# - 通过torch在cpu上推理性低效，只能作为离线生成音频任务的场景
# - 不支持流式输出结果
