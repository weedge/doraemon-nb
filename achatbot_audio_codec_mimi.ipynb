# %% [markdown]
# <a href="https://colab.research.google.com/github/weedge/doraemon-nb/blob/main/achatbot_audio_codec_mimi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # init

# %%
# !rm -rf /content/achatbot && git clone https://github.com/ai-bot-pro/achatbot.git
# Out:
# Cloning into 'achatbot'...
# remote: Enumerating objects: 8212, done.
# remote: Counting objects: 100% (384/384), done.
# remote: Compressing objects: 100% (258/258), done.
# remote: Total 8212 (delta 222), reused 246 (delta 120), pack-reused 7828 (from 2)
# Receiving objects: 100% (8212/8212), 10.96 MiB | 43.49 MiB/s, done.
# Resolving deltas: 100% (4917/4917), done.

# %%
# %cd /content/achatbot
# Out:
# /content/achatbot

# %%
# !bash scripts/pypi_achatbot.sh dev

# %% [markdown]
# # test

# %%
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential

# %% [markdown]
# ## test moshi mimi

# %%
# !pip install -q "dist/achatbot-0.0.8.6-py3-none-any.whl[codec_moshi_mimi]"

# %%
# !huggingface-cli download kyutai/moshiko-pytorch-bf16 tokenizer-e351c8d8-checkpoint125.safetensors --quiet --local-dir ./models/kyutai/moshiko-pytorch-bf16
# Out:
# models/kyutai/moshiko-pytorch-bf16/tokenizer-e351c8d8-checkpoint125.safetensors

# %%
# !CODEC_TAG=codec_moshi_mimi CODEC_MODEL_DIR=./models/kyutai/moshiko-pytorch-bf16 \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# 2025-01-25 13:19:52,514 - chat-bot - INFO - /content/achatbot/src/common/factory.py:69 - get_engine_by_tag - use codec_moshi_mimi engine
# 2025-01-25 13:19:52,514 - chat-bot - INFO - /content/achatbot/src/common/factory.py:34 - get_instance - class: <class 'src.modules.codec.audio.moshi_mimi.MoshiMimiCodec'> args: {'model_dir': './models/kyutai/moshiko-pytorch-bf16', 'device': None}
# 2025-01-25 13:19:53,466 - chat-bot - DEBUG - /content/achatbot/src/common/utils/helper.py:54 - print_model_params - MimiModel(
#   (encoder): SEANetEncoder(
#     (model): Sequential(
#       (0): StreamingConv1d(
#         (conv): NormConv1d(
#           (conv): RawStreamingConv1d(1, 64, kernel_size=(7,), stride=(1,))
#         )
#       )
#       (1): SEANetResnetBlock(
#         (block): Sequential(
#           (0): ELU(alpha=1.0)
#           (1): StreamingConv1d(
#             (conv): NormConv1d(
#               (conv): RawStreamingConv1d(64, 32, kernel_size=(3,), stride=(1,))
#             )
# ...

# %%
from IPython.display import Audio
Audio("codec_moshi_mimi_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## test transformers mimi

# %%
# !pip install -q "dist/achatbot-0.0.8.6-py3-none-any.whl[codec_transformers_mimi]"

# %%
# !huggingface-cli download kyutai/mimi --quiet --local-dir ./models/kyutai/mimi
# Out:
# /content/achatbot/models/kyutai/mimi

# %%
# !CODEC_TAG=codec_transformers_mimi CODEC_MODEL_DIR=./models/kyutai/mimi \
    python -m unittest test.modules.codec.test.TestCodec.test_encode_decode
# Out:
# 2025-01-25 13:36:38,780 - chat-bot - INFO - /content/achatbot/src/common/factory.py:69 - get_engine_by_tag - use codec_transformers_mimi engine
# 2025-01-25 13:36:38,780 - chat-bot - INFO - /content/achatbot/src/common/factory.py:34 - get_instance - class: <class 'src.modules.codec.audio.transformers_mimi.TransformersMimiCodec'> args: {'model_dir': './models/kyutai/mimi', 'device': None}
# /usr/local/lib/python3.11/dist-packages/transformers/models/mimi/modeling_mimi.py:217: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# 2025-01-25 13:36:38,937 - chat-bot - DEBUG - /content/achatbot/src/common/utils/helper.py:54 - print_model_params - MimiModel(
#   (encoder): MimiEncoder(
#     (layers): ModuleList(
# ...

# %%
from IPython.display import Audio
Audio("codec_transformers_mimi_test_codec.wav",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
